# %% [markdown]
# # PHẦN 1

# %%
import os

import matplotlib
matplotlib.use('AGG')

import matplotlib.pyplot as plt
import numpy as np

import keras

from keras.datasets import cifar10
from keras.layers import (Activation, Conv3D, Dense, Dropout, Flatten,
                          MaxPooling3D, MaxPooling2D)

from keras.layers import LeakyReLU
from keras.losses import categorical_crossentropy
from keras.models import Sequential
from keras.optimizers import Adam
#from keras.utils import np_utils
#from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split

#import videoto3d
from tqdm import tqdm

from keras.callbacks import ModelCheckpoint
from keras.models import Model
from keras.layers import Input, Dense

##
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
#from keras.backend.tensorflow_backend import set_session
# Out:
# 2025-09-30 15:00:54.677822: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759244454.889537      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759244454.948846      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Processing data

# %%
import cv2


class Videoto3D:
    def __init__(self, width, height, depth):
        self.width = width
        self.height = height
        self.depth = depth

    def video3d(self, filename, color=False, skip=True):
        
        cap = cv2.VideoCapture(filename)
        
        nframe = cap.get(cv2.CAP_PROP_FRAME_COUNT)
        
        if skip:
            frames = [x * nframe / self.depth for x in range(self.depth)]
        else:
            frames = [x for x in range(self.depth)]
        
        framearray = []

        for i in range(self.depth):
            cap.set(cv2.CAP_PROP_POS_FRAMES, frames[i])
            ret, frame = cap.read()
        
            frame = cv2.resize(frame, (self.height, self.width))
        
            if color:
                framearray.append(frame)
            else:
                framearray.append(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

        cap.release()
        
        return np.array(framearray)

    def get_UCF_classname(self, filename):
        x =  filename[filename.find('_') + 1:filename.find('_', 2)]
        return x

# %%
def plot_history(history, result_dir):
    plt.plot(history.history['accuracy'], marker='.')
    plt.plot(history.history['val_accuracy'], marker='.')
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['accuracy', 'val_accuracy'], loc='lower right')
    # plt.savefig(os.path.join(result_dir, 'model_accuracy.png'))
    plt.close()

    plt.plot(history.history['loss'], marker='.')
    plt.plot(history.history['val_loss'], marker='.')
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend(['loss', 'val_loss'], loc='upper right')
    # plt.savefig(os.path.join(result_dir, 'model_loss.png'))
    plt.close()


def save_history(history, result_dir):
    loss = history.history['loss']
    acc = history.history['accuracy']
    val_loss = history.history['val_loss']
    val_acc = history.history['val_accuracy']
    nb_epoch = len(acc)

    with open(os.path.join(result_dir, 'result.txt'), 'w') as fp:
        fp.write('epoch\tloss\tacc\tval_loss\tval_acc\n')
        for i in range(nb_epoch):
            fp.write('{}\t{}\t{}\t{}\t{}\n'.format(
                i, loss[i], acc[i], val_loss[i], val_acc[i]))
    


def loaddata(video_dir, vid3d, nclass, result_dir, color=False, skip=True):
    
    files = os.listdir(video_dir)    
    X = []
    labels = []
    labellist = []

    pbar = tqdm(total=len(files))

    for filename in files:
    
        pbar.update(1)
        
        if filename == '.DS_Store':
            continue
        
        name = os.path.join(video_dir, filename)

        for v_files in os.listdir(name):

            v_file_path = os.path.join(name, v_files)

            label = vid3d.get_UCF_classname(filename)
            
            if label not in labellist:
                
                if len(labellist) >= nclass:
                    continue

                labellist.append(label)
            
            labels.append(label)
            
            X.append(vid3d.video3d(v_file_path, color=color, skip=skip))

    pbar.close()

    os.makedirs(result_dir, exist_ok=True)
    
    with open(os.path.join(result_dir, 'classes.txt'), 'w') as fp:
        for i in range(len(labellist)):
            fp.write('{}\n'.format(labellist[i]))

    for num, label in enumerate(labellist):
        for i in range(len(labels)):
            if label == labels[i]:
                labels[i] = num
                
    if color:
        return np.array(X).transpose((0, 2, 3, 4, 1)), labels
    else:
        return np.array(X).transpose((0, 2, 3, 1)), labels

# %% [markdown]
# # Chạy với dataset UCF50

# %%
def main():

    print('simple 3D convolution for action recognition')
    batch = 128
    # training epoch
    epoch = 100
    # directory where videos are stored
    videos= '/kaggle/input/ucf50-latest-version/UCF50'
    # Number of classes
    nclass = 50
    output = 'results'
    color  = False
    skip   = True
    depth  = 10

    
    img_rows, img_cols, frames = 32, 32, depth
    channel = 3 if color else 1
    fname_npz = 'dataset_{}_{}_{}.npz'.format(nclass, depth, skip)

    vid3d = Videoto3D(img_rows, img_cols, frames)
    nb_classes = nclass
    if os.path.exists(fname_npz):
        loadeddata = np.load(fname_npz)
        X, Y = loadeddata["X"], loadeddata["Y"]
    else:
        x, y = loaddata(videos, vid3d, nclass,
                        output, color, skip)
        X = x.reshape((x.shape[0], img_rows, img_cols, frames, channel))
        Y = keras.utils.to_categorical(y, nb_classes)

        X = X.astype('float32')
        np.savez(fname_npz, X=X, Y=Y)
        print('Saved dataset to dataset.npz.')
    print('X_shape:{}\nY_shape:{}'.format(X.shape, Y.shape))

    # Define model
    # model = Sequential()


    # model.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 


    # model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 

    ###########################

    input_x = Input(shape = (32, 32, depth, 1))

    initial_conv = Conv3D(16, kernel_size= (3, 3, 3), padding='same')(input_x)
    initial_conv = LeakyReLU(alpha=.001)(initial_conv)

    initial_conv = Conv3D(32, kernel_size= (3, 3, 3), padding='same')(initial_conv)
    initial_conv = LeakyReLU(alpha=.001)(initial_conv)


    ###########################
    # PARALLEL 1

    conv1 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(initial_conv)
    conv1 = LeakyReLU(alpha=.001)(conv1)
    conv1 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv1)


    # conv1 = Conv3D(16, kernel_size=(3, 3, 3),padding='same')(conv1)
    # conv1 = LeakyReLU(alpha=.001)(conv1)

    conv1 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv1)
    conv1 = LeakyReLU(alpha=.001)(conv1)

    
    conv1 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv1)

    # conv1 = Conv3D(8, kernel_size=(1, 1, 1),padding='same')(conv1)

    #check it    
    # conv1 = LeakyReLU(alpha=.001)(conv1)

    # conv1 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv1)

    ##############################

    ##############################

    #Parallel 2

    conv2 = Conv3D(8, kernel_size=(1, 1, 1),padding='same')(initial_conv)
    conv2 = LeakyReLU(alpha=.001)(conv2)
    conv2 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv2)


    # conv2 = Conv3D(8, kernel_size=(3, 3, 3),padding='same')(conv2)
    # conv2 = LeakyReLU(alpha=.001)(conv2)

    conv2 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv2)
    conv2 = LeakyReLU(alpha=.001)(conv2)
    

    conv2 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv2)

    # conv2 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(conv2)

    # #check it    
    # conv2 = LeakyReLU(alpha=.001)(conv2)

    # conv2 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv2)

    ###################################


    ##############################

    #Parallel 3

    conv3 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(initial_conv)
    conv3 = LeakyReLU(alpha=.001)(conv3)
    conv3 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv3)


    # conv3 = Conv3D(4, kernel_size=(3, 3, 3),padding='same')(conv3)
    # conv3 = LeakyReLU(alpha=.001)(conv3)

    conv3 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv3)
    conv3 = LeakyReLU(alpha=.001)(conv3)
    

    conv3 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv3)

    # conv3 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(conv3)

    # #check it    
    # conv3 = LeakyReLU(alpha=.001)(conv3)

    # conv3 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv3)

    ###################################

    added = keras.layers.Add()([conv1, conv2, conv3])

    added = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(added)

    added = Flatten()(added)

    dense_1 = Dense(256)(added)

    dense_2 = Dense(nb_classes, activation = 'softmax')(dense_1)

    model = Model(input_x, dense_2)

    model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(), metrics=['accuracy']) 

    model.summary()
    # plot_model(model, show_shapes=True,
    #            to_file=os.path.join(args.output, 'model.png'))

    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=0.2, random_state=43)
    print(X_train.shape)

    ####################

    # 1
    filepath="d_3dcnnmodel-{epoch:02d}-{val_accuracy:.2f}.weights.hd5.keras"
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    callbacks_list = [checkpoint]

    # 2 

    config = tf.compat.v1.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.3
    set_session(tf.compat.v1.Session(config=config))

    ###############

    # Train model
    history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=batch,
                        epochs=epoch, verbose=1, shuffle=True, callbacks=callbacks_list)
    
    model.evaluate(X_test, Y_test, verbose=0)
    
    model_json = model.to_json()
    
    if not os.path.isdir(output):
        os.makedirs(output)
    with open(os.path.join(output, 'ucf50_3dcnnmodel.json'), 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights(os.path.join(output, 'ucf50_3dcnnmodel-gpu.weights.h5'))

    loss, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test loss:', loss)
    print('Test accuracy:', acc)

    plot_history(history, output)
    save_history(history, output)

# %%
if __name__ == '__main__':
    main()
# Out:
# simple 3D convolution for action recognition
# 100%|██████████| 50/50 [04:48<00:00,  5.77s/it]
# Saved dataset to dataset.npz.
# X_shape:(6669, 32, 32, 10, 1)
# Y_shape:(6669, 50)
# I0000 00:00:1759244786.336050      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32,    │          0 │ -                 │
# │ (InputLayer)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 32, 32,    │        448 │ input_layer[0][0] │
# │                     │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 32, 32,    │          0 │ conv3d[0][0]      │
# │ (LeakyReLU)         │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 32, 32,    │     13,856 │ leaky_re_lu[0][0] │
# │                     │ 10, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 32, 32,    │          0 │ conv3d_1[0][0]    │
# │ (LeakyReLU)         │ 10, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 32, 32,    │        528 │ leaky_re_lu_1[0]… │
# │                     │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 32, 32,    │        264 │ leaky_re_lu_1[0]… │
# │                     │ 10, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_6 (Conv3D)   │ (None, 32, 32,    │        132 │ leaky_re_lu_1[0]… │
# │                     │ 10, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 32, 32,    │          0 │ conv3d_2[0][0]    │
# │ (LeakyReLU)         │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 32, 32,    │          0 │ conv3d_4[0][0]    │
# │ (LeakyReLU)         │ 10, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 32, 32,    │          0 │ conv3d_6[0][0]    │
# │ (LeakyReLU)         │ 10, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d       │ (None, 16, 16, 5, │          0 │ leaky_re_lu_2[0]… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_2     │ (None, 16, 16, 5, │          0 │ leaky_re_lu_4[0]… │
# │ (MaxPooling3D)      │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_4     │ (None, 16, 16, 5, │          0 │ leaky_re_lu_6[0]… │
# │ (MaxPooling3D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 16, 16, 5, │        272 │ max_pooling3d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 16, 16, 5, │        144 │ max_pooling3d_2[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_7 (Conv3D)   │ (None, 16, 16, 5, │         80 │ max_pooling3d_4[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 16, 16, 5, │          0 │ conv3d_3[0][0]    │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 16, 16, 5, │          0 │ conv3d_5[0][0]    │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 16, 16, 5, │          0 │ conv3d_7[0][0]    │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_1     │ (None, 8, 8, 3,   │          0 │ leaky_re_lu_3[0]… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_3     │ (None, 8, 8, 3,   │          0 │ leaky_re_lu_5[0]… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_5     │ (None, 8, 8, 3,   │          0 │ leaky_re_lu_7[0]… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 8, 8, 3,   │          0 │ max_pooling3d_1[… │
# │                     │ 16)               │            │ max_pooling3d_3[… │
# │                     │                   │            │ max_pooling3d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_6     │ (None, 4, 4, 2,   │          0 │ add[0][0]         │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 512)       │          0 │ max_pooling3d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    131,328 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 50)        │     12,850 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 159,902 (624.62 KB)
#  Trainable params: 159,902 (624.62 KB)
#  Non-trainable params: 0 (0.00 B)
# (5335, 32, 32, 10, 1)
# I0000 00:00:1759244788.076585      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759244793.909231   26771 service.cc:148] XLA service 0x788898056770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759244793.910131   26771 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759244794.476155   26771 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-09-30 15:06:38.304398: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,16,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,16,32,32,10]{4,3,2,1,0}, f32[128,32,32,32,10]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:06:38.351685: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.047409204s
# Trying algorithm eng0{} for conv (f32[32,16,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,16,32,32,10]{4,3,2,1,0}, f32[128,32,32,32,10]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
#  2/42 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.0410 - loss: 54.3444
# I0000 00:00:1759244801.159168   26771 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.0255 - loss: 25.2741
# Epoch 1: val_accuracy improved from -inf to 0.02624, saving model to d_3dcnnmodel-01-0.03.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 23s 250ms/step - accuracy: 0.0255 - loss: 25.0057 - val_accuracy: 0.0262 - val_loss: 4.4456
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0361 - loss: 4.2541
# Epoch 2: val_accuracy improved from 0.02624 to 0.03823, saving model to d_3dcnnmodel-02-0.04.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.0361 - loss: 4.2507 - val_accuracy: 0.0382 - val_loss: 3.9612
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0471 - loss: 3.9124
# Epoch 3: val_accuracy improved from 0.03823 to 0.04723, saving model to d_3dcnnmodel-03-0.05.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.0472 - loss: 3.9118 - val_accuracy: 0.0472 - val_loss: 3.8872
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0670 - loss: 3.8337
# Epoch 4: val_accuracy improved from 0.04723 to 0.05772, saving model to d_3dcnnmodel-04-0.06.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.0672 - loss: 3.8333 - val_accuracy: 0.0577 - val_loss: 3.8414
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0841 - loss: 3.7673
# Epoch 5: val_accuracy improved from 0.05772 to 0.07571, saving model to d_3dcnnmodel-05-0.08.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.0842 - loss: 3.7669 - val_accuracy: 0.0757 - val_loss: 3.7829
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0985 - loss: 3.6948
# Epoch 6: val_accuracy improved from 0.07571 to 0.09295, saving model to d_3dcnnmodel-06-0.09.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.0986 - loss: 3.6943 - val_accuracy: 0.0930 - val_loss: 3.6995
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1276 - loss: 3.5933
# Epoch 7: val_accuracy improved from 0.09295 to 0.12744, saving model to d_3dcnnmodel-07-0.13.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.1277 - loss: 3.5924 - val_accuracy: 0.1274 - val_loss: 3.5552
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1580 - loss: 3.4017
# Epoch 8: val_accuracy improved from 0.12744 to 0.15742, saving model to d_3dcnnmodel-08-0.16.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.1582 - loss: 3.4003 - val_accuracy: 0.1574 - val_loss: 3.3126
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2132 - loss: 3.0941
# Epoch 9: val_accuracy improved from 0.15742 to 0.19265, saving model to d_3dcnnmodel-09-0.19.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.2133 - loss: 3.0926 - val_accuracy: 0.1927 - val_loss: 3.0504
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2537 - loss: 2.7910
# Epoch 10: val_accuracy improved from 0.19265 to 0.23613, saving model to d_3dcnnmodel-10-0.24.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.2540 - loss: 2.7902 - val_accuracy: 0.2361 - val_loss: 2.8833
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3244 - loss: 2.5485
# Epoch 11: val_accuracy improved from 0.23613 to 0.26237, saving model to d_3dcnnmodel-11-0.26.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.3240 - loss: 2.5493 - val_accuracy: 0.2624 - val_loss: 2.7621
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3385 - loss: 2.4367
# Epoch 12: val_accuracy improved from 0.26237 to 0.27436, saving model to d_3dcnnmodel-12-0.27.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.3386 - loss: 2.4363 - val_accuracy: 0.2744 - val_loss: 2.6773
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3733 - loss: 2.3138
# Epoch 13: val_accuracy improved from 0.27436 to 0.30135, saving model to d_3dcnnmodel-13-0.30.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.3733 - loss: 2.3138 - val_accuracy: 0.3013 - val_loss: 2.6360
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3979 - loss: 2.1867
# Epoch 14: val_accuracy improved from 0.30135 to 0.32534, saving model to d_3dcnnmodel-14-0.33.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.3979 - loss: 2.1871 - val_accuracy: 0.3253 - val_loss: 2.5771
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4304 - loss: 2.0695
# Epoch 15: val_accuracy improved from 0.32534 to 0.32759, saving model to d_3dcnnmodel-15-0.33.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4304 - loss: 2.0698 - val_accuracy: 0.3276 - val_loss: 2.5437
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4456 - loss: 1.9903
# Epoch 16: val_accuracy improved from 0.32759 to 0.34633, saving model to d_3dcnnmodel-16-0.35.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.4457 - loss: 1.9900 - val_accuracy: 0.3463 - val_loss: 2.5131
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4812 - loss: 1.8659
# Epoch 17: val_accuracy improved from 0.34633 to 0.35682, saving model to d_3dcnnmodel-17-0.36.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.4811 - loss: 1.8668 - val_accuracy: 0.3568 - val_loss: 2.4533
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5053 - loss: 1.8010
# Epoch 18: val_accuracy improved from 0.35682 to 0.36882, saving model to d_3dcnnmodel-18-0.37.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.5051 - loss: 1.8014 - val_accuracy: 0.3688 - val_loss: 2.4265
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5253 - loss: 1.7205
# Epoch 19: val_accuracy improved from 0.36882 to 0.39355, saving model to d_3dcnnmodel-19-0.39.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.5253 - loss: 1.7206 - val_accuracy: 0.3936 - val_loss: 2.3695
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5514 - loss: 1.6085
# Epoch 20: val_accuracy did not improve from 0.39355
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.5512 - loss: 1.6092 - val_accuracy: 0.3808 - val_loss: 2.4240
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5788 - loss: 1.5231
# Epoch 21: val_accuracy did not improve from 0.39355
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.5785 - loss: 1.5238 - val_accuracy: 0.3883 - val_loss: 2.4069
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5863 - loss: 1.4553
# Epoch 22: val_accuracy improved from 0.39355 to 0.40330, saving model to d_3dcnnmodel-22-0.40.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.5862 - loss: 1.4556 - val_accuracy: 0.4033 - val_loss: 2.3496
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6002 - loss: 1.3812
# Epoch 23: val_accuracy improved from 0.40330 to 0.41154, saving model to d_3dcnnmodel-23-0.41.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.6001 - loss: 1.3818 - val_accuracy: 0.4115 - val_loss: 2.3625
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6332 - loss: 1.3532
# Epoch 24: val_accuracy improved from 0.41154 to 0.41754, saving model to d_3dcnnmodel-24-0.42.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.6331 - loss: 1.3527 - val_accuracy: 0.4175 - val_loss: 2.2953
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6554 - loss: 1.2159
# Epoch 25: val_accuracy improved from 0.41754 to 0.43178, saving model to d_3dcnnmodel-25-0.43.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.6554 - loss: 1.2163 - val_accuracy: 0.4318 - val_loss: 2.3400
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6747 - loss: 1.1780
# Epoch 26: val_accuracy improved from 0.43178 to 0.43403, saving model to d_3dcnnmodel-26-0.43.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.6746 - loss: 1.1783 - val_accuracy: 0.4340 - val_loss: 2.3467
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6938 - loss: 1.1084
# Epoch 27: val_accuracy improved from 0.43403 to 0.44603, saving model to d_3dcnnmodel-27-0.45.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.6934 - loss: 1.1091 - val_accuracy: 0.4460 - val_loss: 2.3868
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6933 - loss: 1.0842
# Epoch 28: val_accuracy did not improve from 0.44603
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.6931 - loss: 1.0846 - val_accuracy: 0.4325 - val_loss: 2.3621
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7164 - loss: 1.0162
# Epoch 29: val_accuracy improved from 0.44603 to 0.46177, saving model to d_3dcnnmodel-29-0.46.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.7163 - loss: 1.0162 - val_accuracy: 0.4618 - val_loss: 2.3334
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7448 - loss: 0.9153
# Epoch 30: val_accuracy did not improve from 0.46177
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.7445 - loss: 0.9162 - val_accuracy: 0.4528 - val_loss: 2.3950
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7460 - loss: 0.8891
# Epoch 31: val_accuracy improved from 0.46177 to 0.48201, saving model to d_3dcnnmodel-31-0.48.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.7459 - loss: 0.8899 - val_accuracy: 0.4820 - val_loss: 2.3592
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7595 - loss: 0.8397
# Epoch 32: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7593 - loss: 0.8402 - val_accuracy: 0.4715 - val_loss: 2.4431
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7733 - loss: 0.7795
# Epoch 33: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7731 - loss: 0.7804 - val_accuracy: 0.4595 - val_loss: 2.4903
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7982 - loss: 0.7234
# Epoch 34: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.7980 - loss: 0.7242 - val_accuracy: 0.4618 - val_loss: 2.5217
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8165 - loss: 0.6632
# Epoch 35: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8162 - loss: 0.6640 - val_accuracy: 0.4798 - val_loss: 2.5644
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8216 - loss: 0.6286
# Epoch 36: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8211 - loss: 0.6303 - val_accuracy: 0.4768 - val_loss: 2.6425
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8109 - loss: 0.6511
# Epoch 37: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8108 - loss: 0.6515 - val_accuracy: 0.4633 - val_loss: 2.5965
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8108 - loss: 0.6515
# Epoch 38: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8107 - loss: 0.6516 - val_accuracy: 0.4700 - val_loss: 2.6720
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8383 - loss: 0.5638
# Epoch 39: val_accuracy improved from 0.48201 to 0.48276, saving model to d_3dcnnmodel-39-0.48.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8382 - loss: 0.5642 - val_accuracy: 0.4828 - val_loss: 2.6925
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8591 - loss: 0.4911
# Epoch 40: val_accuracy improved from 0.48276 to 0.48651, saving model to d_3dcnnmodel-40-0.49.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8590 - loss: 0.4915 - val_accuracy: 0.4865 - val_loss: 2.6526
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8841 - loss: 0.4459
# Epoch 41: val_accuracy did not improve from 0.48651
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8838 - loss: 0.4464 - val_accuracy: 0.4768 - val_loss: 2.8317
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8871 - loss: 0.4089
# Epoch 42: val_accuracy improved from 0.48651 to 0.48951, saving model to d_3dcnnmodel-42-0.49.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8870 - loss: 0.4091 - val_accuracy: 0.4895 - val_loss: 2.7656
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8855 - loss: 0.3990
# Epoch 43: val_accuracy did not improve from 0.48951
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8853 - loss: 0.3994 - val_accuracy: 0.4835 - val_loss: 2.9263
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9003 - loss: 0.3497
# Epoch 44: val_accuracy did not improve from 0.48951
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8999 - loss: 0.3508 - val_accuracy: 0.4873 - val_loss: 2.9210
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9062 - loss: 0.3364
# Epoch 45: val_accuracy improved from 0.48951 to 0.49250, saving model to d_3dcnnmodel-45-0.49.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9061 - loss: 0.3367 - val_accuracy: 0.4925 - val_loss: 2.9345
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9209 - loss: 0.2981
# Epoch 46: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9205 - loss: 0.2991 - val_accuracy: 0.4858 - val_loss: 3.0918
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9160 - loss: 0.3037
# Epoch 47: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9157 - loss: 0.3046 - val_accuracy: 0.4813 - val_loss: 3.1790
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8856 - loss: 0.3638
# Epoch 48: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8855 - loss: 0.3642 - val_accuracy: 0.4798 - val_loss: 3.1672
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8953 - loss: 0.3395
# Epoch 49: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8953 - loss: 0.3395 - val_accuracy: 0.4813 - val_loss: 3.1653
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9257 - loss: 0.2643
# Epoch 50: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9256 - loss: 0.2643 - val_accuracy: 0.4873 - val_loss: 3.2271
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9310 - loss: 0.2477
# Epoch 51: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9308 - loss: 0.2481 - val_accuracy: 0.4910 - val_loss: 3.3243
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9298 - loss: 0.2441
# Epoch 52: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9297 - loss: 0.2442 - val_accuracy: 0.4843 - val_loss: 3.2990
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9431 - loss: 0.2085
# Epoch 53: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9430 - loss: 0.2087 - val_accuracy: 0.4873 - val_loss: 3.3483
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9359 - loss: 0.2323
# Epoch 54: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9358 - loss: 0.2324 - val_accuracy: 0.4783 - val_loss: 3.5347
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9306 - loss: 0.2271
# Epoch 55: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9303 - loss: 0.2278 - val_accuracy: 0.4715 - val_loss: 3.6926
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9259 - loss: 0.2387
# Epoch 56: val_accuracy did not improve from 0.49250
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9260 - loss: 0.2386 - val_accuracy: 0.4918 - val_loss: 3.5600
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9581 - loss: 0.1618
# Epoch 57: val_accuracy improved from 0.49250 to 0.50075, saving model to d_3dcnnmodel-57-0.50.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9581 - loss: 0.1618 - val_accuracy: 0.5007 - val_loss: 3.5274
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9735 - loss: 0.1201
# Epoch 58: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9735 - loss: 0.1201 - val_accuracy: 0.4843 - val_loss: 3.7414
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9680 - loss: 0.1225
# Epoch 59: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9679 - loss: 0.1228 - val_accuracy: 0.4888 - val_loss: 3.8127
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9490 - loss: 0.1752
# Epoch 60: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9488 - loss: 0.1756 - val_accuracy: 0.4850 - val_loss: 3.7446
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9532 - loss: 0.1592
# Epoch 61: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9531 - loss: 0.1594 - val_accuracy: 0.4970 - val_loss: 3.7683
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9409 - loss: 0.1967
# Epoch 62: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9406 - loss: 0.1976 - val_accuracy: 0.4715 - val_loss: 4.0607
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9195 - loss: 0.2337
# Epoch 63: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9197 - loss: 0.2333 - val_accuracy: 0.4835 - val_loss: 3.8814
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9423 - loss: 0.1938
# Epoch 64: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9421 - loss: 0.1942 - val_accuracy: 0.4873 - val_loss: 4.0497
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9446 - loss: 0.1770
# Epoch 65: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9446 - loss: 0.1769 - val_accuracy: 0.4858 - val_loss: 4.0506
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9580 - loss: 0.1394
# Epoch 66: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9579 - loss: 0.1395 - val_accuracy: 0.4948 - val_loss: 3.9525
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9625 - loss: 0.1248
# Epoch 67: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9625 - loss: 0.1250 - val_accuracy: 0.4880 - val_loss: 4.0921
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9712 - loss: 0.1134
# Epoch 68: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9712 - loss: 0.1133 - val_accuracy: 0.4925 - val_loss: 4.2007
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9791 - loss: 0.0812
# Epoch 69: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9791 - loss: 0.0812 - val_accuracy: 0.4940 - val_loss: 4.1488
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9738 - loss: 0.0972
# Epoch 70: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9736 - loss: 0.0979 - val_accuracy: 0.4745 - val_loss: 4.4713
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9510 - loss: 0.1618
# Epoch 71: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9509 - loss: 0.1622 - val_accuracy: 0.4895 - val_loss: 4.5099
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9136 - loss: 0.2675
# Epoch 72: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9134 - loss: 0.2681 - val_accuracy: 0.4693 - val_loss: 4.5290
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8903 - loss: 0.3185
# Epoch 73: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8901 - loss: 0.3192 - val_accuracy: 0.4753 - val_loss: 4.4876
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9193 - loss: 0.2590
# Epoch 74: val_accuracy did not improve from 0.50075
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9192 - loss: 0.2592 - val_accuracy: 0.4880 - val_loss: 4.2787
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9165 - loss: 0.2671
# Epoch 75: val_accuracy improved from 0.50075 to 0.50675, saving model to d_3dcnnmodel-75-0.51.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9168 - loss: 0.2661 - val_accuracy: 0.5067 - val_loss: 4.2470
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9564 - loss: 0.1435
# Epoch 76: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9564 - loss: 0.1436 - val_accuracy: 0.4918 - val_loss: 4.6046
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9400 - loss: 0.1890
# Epoch 77: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9400 - loss: 0.1891 - val_accuracy: 0.4918 - val_loss: 4.4571
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9489 - loss: 0.1506
# Epoch 78: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9489 - loss: 0.1506 - val_accuracy: 0.4895 - val_loss: 4.5189
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9661 - loss: 0.1132
# Epoch 79: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9662 - loss: 0.1131 - val_accuracy: 0.4963 - val_loss: 4.4966
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9793 - loss: 0.0699
# Epoch 80: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9791 - loss: 0.0704 - val_accuracy: 0.4873 - val_loss: 4.4367
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9763 - loss: 0.0831
# Epoch 81: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9762 - loss: 0.0831 - val_accuracy: 0.5000 - val_loss: 4.4676
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9804 - loss: 0.0668
# Epoch 82: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9804 - loss: 0.0669 - val_accuracy: 0.4858 - val_loss: 4.6855
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9877 - loss: 0.0490
# Epoch 83: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9877 - loss: 0.0491 - val_accuracy: 0.4940 - val_loss: 4.6766
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9886 - loss: 0.0534
# Epoch 84: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9885 - loss: 0.0535 - val_accuracy: 0.5000 - val_loss: 4.9100
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9693 - loss: 0.0917
# Epoch 85: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9693 - loss: 0.0918 - val_accuracy: 0.4925 - val_loss: 4.8802
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9709 - loss: 0.1012
# Epoch 86: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9709 - loss: 0.1011 - val_accuracy: 0.4798 - val_loss: 4.9748
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9766 - loss: 0.0860
# Epoch 87: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9765 - loss: 0.0862 - val_accuracy: 0.4790 - val_loss: 4.7903
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9583 - loss: 0.1324
# Epoch 88: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9579 - loss: 0.1338 - val_accuracy: 0.4948 - val_loss: 4.9529
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9290 - loss: 0.2437
# Epoch 89: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9289 - loss: 0.2436 - val_accuracy: 0.4805 - val_loss: 4.8967
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9275 - loss: 0.2281
# Epoch 90: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9274 - loss: 0.2286 - val_accuracy: 0.4933 - val_loss: 4.6713
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9549 - loss: 0.1445
# Epoch 91: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9548 - loss: 0.1447 - val_accuracy: 0.4850 - val_loss: 5.0275
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9646 - loss: 0.1138
# Epoch 92: val_accuracy did not improve from 0.50675
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9645 - loss: 0.1141 - val_accuracy: 0.4895 - val_loss: 4.9600
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9697 - loss: 0.0918
# Epoch 93: val_accuracy improved from 0.50675 to 0.50825, saving model to d_3dcnnmodel-93-0.51.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9697 - loss: 0.0919 - val_accuracy: 0.5082 - val_loss: 4.7308
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9808 - loss: 0.0631
# Epoch 94: val_accuracy did not improve from 0.50825
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9806 - loss: 0.0635 - val_accuracy: 0.4993 - val_loss: 5.0065
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9742 - loss: 0.0901
# Epoch 95: val_accuracy did not improve from 0.50825
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9741 - loss: 0.0901 - val_accuracy: 0.4850 - val_loss: 4.9350
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9716 - loss: 0.0815
# Epoch 96: val_accuracy improved from 0.50825 to 0.51499, saving model to d_3dcnnmodel-96-0.51.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9717 - loss: 0.0815 - val_accuracy: 0.5150 - val_loss: 5.0413
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9810 - loss: 0.0619
# Epoch 97: val_accuracy did not improve from 0.51499
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9810 - loss: 0.0620 - val_accuracy: 0.4978 - val_loss: 5.1366
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9788 - loss: 0.0655
# Epoch 98: val_accuracy did not improve from 0.51499
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9787 - loss: 0.0658 - val_accuracy: 0.4865 - val_loss: 5.3844
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9747 - loss: 0.0771
# Epoch 99: val_accuracy did not improve from 0.51499
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9749 - loss: 0.0768 - val_accuracy: 0.5120 - val_loss: 5.0952
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9847 - loss: 0.0522
# Epoch 100: val_accuracy did not improve from 0.51499
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9847 - loss: 0.0522 - val_accuracy: 0.5060 - val_loss: 5.2859
# Test loss: 5.285865783691406
# Test accuracy: 0.5059970021247864

# %% [markdown]
# # Sử dụng tích chập với filter 5x5x5.

# %%
def main():

    print('simple 3D convolution for action recognition')
    batch = 128
    # training epoch
    epoch = 100
    # directory where videos are stored
    videos= '/kaggle/input/ucf50-latest-version/UCF50'
    # Number of classes
    nclass = 50
    output = 'results_1'
    color  = False
    skip   = True
    depth  = 10

    
    img_rows, img_cols, frames = 32, 32, depth
    channel = 3 if color else 1
    fname_npz = 'dataset_{}_{}_{}.npz'.format(nclass, depth, skip)

    vid3d = Videoto3D(img_rows, img_cols, frames)
    nb_classes = nclass
    if os.path.exists(fname_npz):
        loadeddata = np.load(fname_npz)
        X, Y = loadeddata["X"], loadeddata["Y"]
    else:
        x, y = loaddata(videos, vid3d, nclass,
                        output, color, skip)
        X = x.reshape((x.shape[0], img_rows, img_cols, frames, channel))
        Y = keras.utils.to_categorical(y, nb_classes)

        X = X.astype('float32')
        np.savez(fname_npz, X=X, Y=Y)
        print('Saved dataset to dataset.npz.')
    print('X_shape:{}\nY_shape:{}'.format(X.shape, Y.shape))

    # Define model
    # model = Sequential()


    # model.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 


    # model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 

    ###########################

    input_x = Input(shape = (32, 32, depth, 1))

    initial_conv = Conv3D(16, kernel_size= (3, 3, 3), padding='same')(input_x)
    initial_conv = LeakyReLU(alpha=.001)(initial_conv)

    initial_conv = Conv3D(32, kernel_size= (3, 3, 3), padding='same')(initial_conv)
    initial_conv = LeakyReLU(alpha=.001)(initial_conv)


    ###########################
    # PARALLEL 1

    conv1 = Conv3D(16, kernel_size=(5, 5, 5),padding='same')(initial_conv)
    conv1 = LeakyReLU(alpha=.001)(conv1)
    conv1 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv1)


    # conv1 = Conv3D(16, kernel_size=(3, 3, 3),padding='same')(conv1)
    # conv1 = LeakyReLU(alpha=.001)(conv1)

    conv1 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv1)
    conv1 = LeakyReLU(alpha=.001)(conv1)

    
    conv1 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv1)

    # conv1 = Conv3D(8, kernel_size=(1, 1, 1),padding='same')(conv1)

    #check it    
    # conv1 = LeakyReLU(alpha=.001)(conv1)

    # conv1 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv1)

    ##############################

    ##############################

    #Parallel 2

    conv2 = Conv3D(8, kernel_size=(5, 5, 5),padding='same')(initial_conv)
    conv2 = LeakyReLU(alpha=.001)(conv2)
    conv2 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv2)


    # conv2 = Conv3D(8, kernel_size=(3, 3, 3),padding='same')(conv2)
    # conv2 = LeakyReLU(alpha=.001)(conv2)

    conv2 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv2)
    conv2 = LeakyReLU(alpha=.001)(conv2)
    

    conv2 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv2)

    # conv2 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(conv2)

    # #check it    
    # conv2 = LeakyReLU(alpha=.001)(conv2)

    # conv2 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv2)

    ###################################


    ##############################

    #Parallel 3

    conv3 = Conv3D(4, kernel_size=(5, 5, 5),padding='same')(initial_conv)
    conv3 = LeakyReLU(alpha=.001)(conv3)
    conv3 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv3)


    # conv3 = Conv3D(4, kernel_size=(3, 3, 3),padding='same')(conv3)
    # conv3 = LeakyReLU(alpha=.001)(conv3)

    conv3 = Conv3D(16, kernel_size=(1, 1, 1),padding='same')(conv3)
    conv3 = LeakyReLU(alpha=.001)(conv3)
    

    conv3 = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(conv3)

    # conv3 = Conv3D(4, kernel_size=(1, 1, 1),padding='same')(conv3)

    # #check it    
    # conv3 = LeakyReLU(alpha=.001)(conv3)

    # conv3 = Conv3D(1, kernel_size=(1, 1, 1),padding='same')(conv3)

    ###################################

    added = keras.layers.Add()([conv1, conv2, conv3])

    added = MaxPooling3D(pool_size=(2, 2, 2), padding='same')(added)

    added = Flatten()(added)

    dense_1 = Dense(256)(added)

    dense_2 = Dense(nb_classes, activation = 'softmax')(dense_1)

    model = Model(input_x, dense_2)

    model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(), metrics=['accuracy']) 

    model.summary()
    # plot_model(model, show_shapes=True,
    #            to_file=os.path.join(args.output, 'model.png'))

    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=0.2, random_state=43)
    print(X_train.shape)

    ####################

    # 1
    filepath="d_3dcnnmodel-{epoch:02d}-{val_accuracy:.2f}.weights.hd5.keras"
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    callbacks_list = [checkpoint]

    # 2 

    config = tf.compat.v1.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.3
    set_session(tf.compat.v1.Session(config=config))

    ###############

    # Train model
    history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=batch,
                        epochs=epoch, verbose=1, shuffle=True, callbacks=callbacks_list)
    
    model.evaluate(X_test, Y_test, verbose=0)
    
    model_json = model.to_json()
    
    if not os.path.isdir(output):
        os.makedirs(output)
    with open(os.path.join(output, 'ucf50_3dcnnmodel.json'), 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights(os.path.join(output, 'ucf50_3dcnnmodel-gpu.weights.h5'))

    loss, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test loss:', loss)
    print('Test accuracy:', acc)

    plot_history(history, output)
    save_history(history, output)

# %%
if __name__ == '__main__':
    main()
# Out:
# simple 3D convolution for action recognition
# X_shape:(6669, 32, 32, 10, 1)
# Y_shape:(6669, 50)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 32, 32,    │          0 │ -                 │
# │ (InputLayer)        │ 10, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_8 (Conv3D)   │ (None, 32, 32,    │        448 │ input_layer_1[0]… │
# │                     │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 32, 32,    │          0 │ conv3d_8[0][0]    │
# │ (LeakyReLU)         │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_9 (Conv3D)   │ (None, 32, 32,    │     13,856 │ leaky_re_lu_8[0]… │
# │                     │ 10, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 32, 32,    │          0 │ conv3d_9[0][0]    │
# │ (LeakyReLU)         │ 10, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_10 (Conv3D)  │ (None, 32, 32,    │     64,016 │ leaky_re_lu_9[0]… │
# │                     │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_12 (Conv3D)  │ (None, 32, 32,    │     32,008 │ leaky_re_lu_9[0]… │
# │                     │ 10, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_14 (Conv3D)  │ (None, 32, 32,    │     16,004 │ leaky_re_lu_9[0]… │
# │                     │ 10, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 32, 32,    │          0 │ conv3d_10[0][0]   │
# │ (LeakyReLU)         │ 10, 16)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ conv3d_12[0][0]   │
# │ (LeakyReLU)         │ 10, 8)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 32, 32,    │          0 │ conv3d_14[0][0]   │
# │ (LeakyReLU)         │ 10, 4)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_7     │ (None, 16, 16, 5, │          0 │ leaky_re_lu_10[0… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_9     │ (None, 16, 16, 5, │          0 │ leaky_re_lu_12[0… │
# │ (MaxPooling3D)      │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_11    │ (None, 16, 16, 5, │          0 │ leaky_re_lu_14[0… │
# │ (MaxPooling3D)      │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_11 (Conv3D)  │ (None, 16, 16, 5, │        272 │ max_pooling3d_7[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_13 (Conv3D)  │ (None, 16, 16, 5, │        144 │ max_pooling3d_9[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_15 (Conv3D)  │ (None, 16, 16, 5, │         80 │ max_pooling3d_11… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 16, 16, 5, │          0 │ conv3d_11[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 16, 16, 5, │          0 │ conv3d_13[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 16, 16, 5, │          0 │ conv3d_15[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_8     │ (None, 8, 8, 3,   │          0 │ leaky_re_lu_11[0… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_10    │ (None, 8, 8, 3,   │          0 │ leaky_re_lu_13[0… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_12    │ (None, 8, 8, 3,   │          0 │ leaky_re_lu_15[0… │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 8, 8, 3,   │          0 │ max_pooling3d_8[… │
# │                     │ 16)               │            │ max_pooling3d_10… │
# │                     │                   │            │ max_pooling3d_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_13    │ (None, 4, 4, 2,   │          0 │ add_1[0][0]       │
# │ (MaxPooling3D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 512)       │          0 │ max_pooling3d_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 50)        │     12,850 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 271,006 (1.03 MB)
#  Trainable params: 271,006 (1.03 MB)
#  Non-trainable params: 0 (0.00 B)
# (5335, 32, 32, 10, 1)
# I0000 00:00:1759245680.362265      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Epoch 1/100
# 2025-09-30 15:21:28.256740: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[128,16,32,32,10]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[16,32,5,5,5]{4,3,2,1,0}, f32[16]{0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:28.714657: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.45807s
# Trying algorithm eng0{} for conv (f32[128,16,32,32,10]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[16,32,5,5,5]{4,3,2,1,0}, f32[16]{0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:39.089889: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k3=0} for conv (f32[4,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,4,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:39.332049: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.24232876s
# Trying algorithm eng20{k2=2,k3=0} for conv (f32[4,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,4,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:40.332287: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[4,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,4,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:40.553588: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.221409237s
# Trying algorithm eng0{} for conv (f32[4,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,4,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:45.093987: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k3=0} for conv (f32[8,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,8,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:45.336248: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.242440136s
# Trying algorithm eng20{k2=2,k3=0} for conv (f32[8,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,8,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:46.336579: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[8,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,8,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:47.738180: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.401767226s
# Trying algorithm eng0{} for conv (f32[8,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,8,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:52.276397: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=2,k3=0} for conv (f32[16,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,16,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:52.520427: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.244229674s
# Trying algorithm eng20{k2=2,k3=0} for conv (f32[16,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,16,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:53.520732: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[16,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,16,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:21:57.268751: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.748185732s
# Trying algorithm eng0{} for conv (f32[16,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,16,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.0199 - loss: 32.0493
# 2025-09-30 15:22:25.630036: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[8,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[87,32,32,32,10]{4,3,2,1,0}, f32[87,8,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:22:26.267645: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.637836544s
# Trying algorithm eng0{} for conv (f32[8,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[87,32,32,32,10]{4,3,2,1,0}, f32[87,8,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:22:31.161324: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[16,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[87,32,32,32,10]{4,3,2,1,0}, f32[87,16,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:22:33.389775: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.228615669s
# Trying algorithm eng0{} for conv (f32[16,32,5,5,5]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[87,32,32,32,10]{4,3,2,1,0}, f32[87,16,32,32,10]{4,3,2,1,0}), window={size=5x5x5 pad=2_2x2_2x2_2}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 880ms/step - accuracy: 0.0198 - loss: 31.5965
# Epoch 1: val_accuracy improved from -inf to 0.03148, saving model to d_3dcnnmodel-01-0.03.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 79s 980ms/step - accuracy: 0.0198 - loss: 31.1649 - val_accuracy: 0.0315 - val_loss: 4.1856
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.0204 - loss: 4.1291
# Epoch 2: val_accuracy did not improve from 0.03148
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.0204 - loss: 4.1269 - val_accuracy: 0.0277 - val_loss: 3.9064
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.0376 - loss: 3.8996
# Epoch 3: val_accuracy improved from 0.03148 to 0.05622, saving model to d_3dcnnmodel-03-0.06.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.0377 - loss: 3.8993 - val_accuracy: 0.0562 - val_loss: 3.8701
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.0692 - loss: 3.8516
# Epoch 4: val_accuracy improved from 0.05622 to 0.06822, saving model to d_3dcnnmodel-04-0.07.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.0693 - loss: 3.8515 - val_accuracy: 0.0682 - val_loss: 3.8289
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.0830 - loss: 3.7961
# Epoch 5: val_accuracy improved from 0.06822 to 0.07196, saving model to d_3dcnnmodel-05-0.07.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.0830 - loss: 3.7959 - val_accuracy: 0.0720 - val_loss: 3.7894
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.0863 - loss: 3.7410
# Epoch 6: val_accuracy improved from 0.07196 to 0.09220, saving model to d_3dcnnmodel-06-0.09.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.0864 - loss: 3.7409 - val_accuracy: 0.0922 - val_loss: 3.7620
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.1048 - loss: 3.6908
# Epoch 7: val_accuracy improved from 0.09220 to 0.10420, saving model to d_3dcnnmodel-07-0.10.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.1049 - loss: 3.6903 - val_accuracy: 0.1042 - val_loss: 3.7047
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.1219 - loss: 3.5929
# Epoch 8: val_accuracy improved from 0.10420 to 0.11694, saving model to d_3dcnnmodel-08-0.12.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.1221 - loss: 3.5921 - val_accuracy: 0.1169 - val_loss: 3.5888
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.1523 - loss: 3.4680
# Epoch 9: val_accuracy improved from 0.11694 to 0.14543, saving model to d_3dcnnmodel-09-0.15.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.1524 - loss: 3.4672 - val_accuracy: 0.1454 - val_loss: 3.4793
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.1963 - loss: 3.2649
# Epoch 10: val_accuracy improved from 0.14543 to 0.18666, saving model to d_3dcnnmodel-10-0.19.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.1964 - loss: 3.2646 - val_accuracy: 0.1867 - val_loss: 3.3143
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.2270 - loss: 3.0924
# Epoch 11: val_accuracy improved from 0.18666 to 0.22414, saving model to d_3dcnnmodel-11-0.22.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.2271 - loss: 3.0915 - val_accuracy: 0.2241 - val_loss: 3.1291
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.2929 - loss: 2.7985
# Epoch 12: val_accuracy improved from 0.22414 to 0.25112, saving model to d_3dcnnmodel-12-0.25.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.2927 - loss: 2.7988 - val_accuracy: 0.2511 - val_loss: 2.9706
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.3162 - loss: 2.6397
# Epoch 13: val_accuracy improved from 0.25112 to 0.29010, saving model to d_3dcnnmodel-13-0.29.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.3163 - loss: 2.6391 - val_accuracy: 0.2901 - val_loss: 2.8470
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.3739 - loss: 2.4021
# Epoch 14: val_accuracy improved from 0.29010 to 0.30885, saving model to d_3dcnnmodel-14-0.31.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.3738 - loss: 2.4025 - val_accuracy: 0.3088 - val_loss: 2.7383
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.4245 - loss: 2.1966
# Epoch 15: val_accuracy improved from 0.30885 to 0.32984, saving model to d_3dcnnmodel-15-0.33.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.4243 - loss: 2.1973 - val_accuracy: 0.3298 - val_loss: 2.6271
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.4698 - loss: 2.0535
# Epoch 16: val_accuracy improved from 0.32984 to 0.33808, saving model to d_3dcnnmodel-16-0.34.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.4697 - loss: 2.0531 - val_accuracy: 0.3381 - val_loss: 2.5993
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.5046 - loss: 1.8611
# Epoch 17: val_accuracy improved from 0.33808 to 0.34408, saving model to d_3dcnnmodel-17-0.34.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.5043 - loss: 1.8617 - val_accuracy: 0.3441 - val_loss: 2.5682
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.5410 - loss: 1.6962
# Epoch 18: val_accuracy improved from 0.34408 to 0.37256, saving model to d_3dcnnmodel-18-0.37.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.5409 - loss: 1.6970 - val_accuracy: 0.3726 - val_loss: 2.4817
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.5919 - loss: 1.4969
# Epoch 19: val_accuracy improved from 0.37256 to 0.40255, saving model to d_3dcnnmodel-19-0.40.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.5918 - loss: 1.4976 - val_accuracy: 0.4025 - val_loss: 2.4456
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6287 - loss: 1.3500
# Epoch 20: val_accuracy improved from 0.40255 to 0.41154, saving model to d_3dcnnmodel-20-0.41.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.6283 - loss: 1.3514 - val_accuracy: 0.4115 - val_loss: 2.4516
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6620 - loss: 1.2239
# Epoch 21: val_accuracy improved from 0.41154 to 0.42054, saving model to d_3dcnnmodel-21-0.42.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.6618 - loss: 1.2246 - val_accuracy: 0.4205 - val_loss: 2.3967
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6941 - loss: 1.1353
# Epoch 22: val_accuracy improved from 0.42054 to 0.42354, saving model to d_3dcnnmodel-22-0.42.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.6940 - loss: 1.1355 - val_accuracy: 0.4235 - val_loss: 2.4526
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.7437 - loss: 0.9504
# Epoch 23: val_accuracy improved from 0.42354 to 0.44153, saving model to d_3dcnnmodel-23-0.44.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.7432 - loss: 0.9517 - val_accuracy: 0.4415 - val_loss: 2.4638
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.7676 - loss: 0.8632
# Epoch 24: val_accuracy did not improve from 0.44153
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.7673 - loss: 0.8640 - val_accuracy: 0.4363 - val_loss: 2.4778
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.7723 - loss: 0.8103
# Epoch 25: val_accuracy improved from 0.44153 to 0.45352, saving model to d_3dcnnmodel-25-0.45.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.7722 - loss: 0.8105 - val_accuracy: 0.4535 - val_loss: 2.4589
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8079 - loss: 0.7180
# Epoch 26: val_accuracy did not improve from 0.45352
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.8079 - loss: 0.7179 - val_accuracy: 0.4385 - val_loss: 2.6282
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8319 - loss: 0.6359
# Epoch 27: val_accuracy improved from 0.45352 to 0.45427, saving model to d_3dcnnmodel-27-0.45.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.8317 - loss: 0.6362 - val_accuracy: 0.4543 - val_loss: 2.7770
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8625 - loss: 0.5200
# Epoch 28: val_accuracy improved from 0.45427 to 0.46702, saving model to d_3dcnnmodel-28-0.47.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.8621 - loss: 0.5213 - val_accuracy: 0.4670 - val_loss: 2.7182
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8550 - loss: 0.5132
# Epoch 29: val_accuracy did not improve from 0.46702
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.8548 - loss: 0.5135 - val_accuracy: 0.4610 - val_loss: 2.7155
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8925 - loss: 0.4118
# Epoch 30: val_accuracy did not improve from 0.46702
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.8922 - loss: 0.4124 - val_accuracy: 0.4610 - val_loss: 2.8747
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9002 - loss: 0.3799
# Epoch 31: val_accuracy did not improve from 0.46702
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9003 - loss: 0.3795 - val_accuracy: 0.4633 - val_loss: 3.0209
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9241 - loss: 0.3036
# Epoch 32: val_accuracy improved from 0.46702 to 0.47376, saving model to d_3dcnnmodel-32-0.47.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.9239 - loss: 0.3039 - val_accuracy: 0.4738 - val_loss: 2.9742
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9367 - loss: 0.2415
# Epoch 33: val_accuracy did not improve from 0.47376
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9366 - loss: 0.2419 - val_accuracy: 0.4730 - val_loss: 3.1930
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9359 - loss: 0.2571
# Epoch 34: val_accuracy did not improve from 0.47376
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9357 - loss: 0.2574 - val_accuracy: 0.4693 - val_loss: 3.1623
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9500 - loss: 0.2100
# Epoch 35: val_accuracy improved from 0.47376 to 0.48201, saving model to d_3dcnnmodel-35-0.48.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 0.9500 - loss: 0.2099 - val_accuracy: 0.4820 - val_loss: 3.3800
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9556 - loss: 0.1717
# Epoch 36: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9556 - loss: 0.1718 - val_accuracy: 0.4670 - val_loss: 3.3402
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9642 - loss: 0.1633
# Epoch 37: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9642 - loss: 0.1631 - val_accuracy: 0.4768 - val_loss: 3.4762
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9706 - loss: 0.1220
# Epoch 38: val_accuracy did not improve from 0.48201
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9706 - loss: 0.1220 - val_accuracy: 0.4625 - val_loss: 3.7360
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9812 - loss: 0.0926
# Epoch 39: val_accuracy improved from 0.48201 to 0.49475, saving model to d_3dcnnmodel-39-0.49.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.9811 - loss: 0.0930 - val_accuracy: 0.4948 - val_loss: 3.5842
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9755 - loss: 0.1108
# Epoch 40: val_accuracy did not improve from 0.49475
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9754 - loss: 0.1113 - val_accuracy: 0.4543 - val_loss: 3.8181
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9582 - loss: 0.1573
# Epoch 41: val_accuracy did not improve from 0.49475
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9578 - loss: 0.1583 - val_accuracy: 0.4498 - val_loss: 3.9384
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9041 - loss: 0.3137
# Epoch 42: val_accuracy did not improve from 0.49475
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9036 - loss: 0.3151 - val_accuracy: 0.4153 - val_loss: 4.0905
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.8489 - loss: 0.4977
# Epoch 43: val_accuracy did not improve from 0.49475
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.8491 - loss: 0.4969 - val_accuracy: 0.4618 - val_loss: 3.7987
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9089 - loss: 0.3044
# Epoch 44: val_accuracy did not improve from 0.49475
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9089 - loss: 0.3043 - val_accuracy: 0.4730 - val_loss: 3.7713
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9466 - loss: 0.1754
# Epoch 45: val_accuracy did not improve from 0.49475
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.9467 - loss: 0.1752 - val_accuracy: 0.4820 - val_loss: 3.6754
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9718 - loss: 0.1112
# Epoch 46: val_accuracy improved from 0.49475 to 0.49625, saving model to d_3dcnnmodel-46-0.50.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.9717 - loss: 0.1113 - val_accuracy: 0.4963 - val_loss: 3.8119
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9809 - loss: 0.0827
# Epoch 47: val_accuracy improved from 0.49625 to 0.50900, saving model to d_3dcnnmodel-47-0.51.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.9809 - loss: 0.0827 - val_accuracy: 0.5090 - val_loss: 3.9229
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9901 - loss: 0.0497
# Epoch 48: val_accuracy did not improve from 0.50900
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 0.9902 - loss: 0.0496 - val_accuracy: 0.5082 - val_loss: 3.9227
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9959 - loss: 0.0287
# Epoch 49: val_accuracy improved from 0.50900 to 0.52024, saving model to d_3dcnnmodel-49-0.52.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 276ms/step - accuracy: 0.9959 - loss: 0.0287 - val_accuracy: 0.5202 - val_loss: 3.9506
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9977 - loss: 0.0209
# Epoch 50: val_accuracy improved from 0.52024 to 0.52624, saving model to d_3dcnnmodel-50-0.53.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 277ms/step - accuracy: 0.9977 - loss: 0.0208 - val_accuracy: 0.5262 - val_loss: 4.0559
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9994 - loss: 0.0108
# Epoch 51: val_accuracy improved from 0.52624 to 0.53223, saving model to d_3dcnnmodel-51-0.53.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 277ms/step - accuracy: 0.9994 - loss: 0.0108 - val_accuracy: 0.5322 - val_loss: 4.1571
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 52: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.5262 - val_loss: 4.2436
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9998 - loss: 0.0060
# Epoch 53: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 0.9998 - loss: 0.0060 - val_accuracy: 0.5277 - val_loss: 4.2591
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 54: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.5180 - val_loss: 4.3507
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 55: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.5187 - val_loss: 4.3992
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 56: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.5240 - val_loss: 4.4922
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 57: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5217 - val_loss: 4.4469
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 58: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.5210 - val_loss: 4.5295
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 59: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5232 - val_loss: 4.5263
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 60: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5240 - val_loss: 4.5824
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 61: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5225 - val_loss: 4.6501
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 62: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5217 - val_loss: 4.6426
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 63: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5210 - val_loss: 4.6817
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 64: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5232 - val_loss: 4.6806
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 65: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5187 - val_loss: 4.7086
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 66: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5210 - val_loss: 4.7465
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 67: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5202 - val_loss: 4.7673
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 68: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5165 - val_loss: 4.7936
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 69: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5180 - val_loss: 4.7832
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 70: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5157 - val_loss: 4.8380
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 71: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5172 - val_loss: 4.8455
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 72: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5165 - val_loss: 4.8855
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 73: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5172 - val_loss: 4.8706
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 74: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5165 - val_loss: 4.9115
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 75: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5187 - val_loss: 4.9237
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 76: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5157 - val_loss: 4.9416
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 77: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5165 - val_loss: 4.9614
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 9.1596e-04
# Epoch 78: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 9.1697e-04 - val_accuracy: 0.5165 - val_loss: 4.9723
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 9.3025e-04
# Epoch 79: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 9.3005e-04 - val_accuracy: 0.5165 - val_loss: 4.9888
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 8.2937e-04
# Epoch 80: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 8.3086e-04 - val_accuracy: 0.5142 - val_loss: 5.0000
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 7.7123e-04
# Epoch 81: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 7.7304e-04 - val_accuracy: 0.5172 - val_loss: 5.0246
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 1.0000 - loss: 8.3395e-04
# Epoch 82: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 8.3347e-04 - val_accuracy: 0.5172 - val_loss: 5.0323
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 7.6253e-04
# Epoch 83: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 7.6293e-04 - val_accuracy: 0.5165 - val_loss: 5.0538
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 7.3484e-04
# Epoch 84: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 7.3525e-04 - val_accuracy: 0.5172 - val_loss: 5.0954
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 7.4065e-04
# Epoch 85: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 7.4028e-04 - val_accuracy: 0.5157 - val_loss: 5.0817
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 6.5720e-04
# Epoch 86: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 6.5815e-04 - val_accuracy: 0.5157 - val_loss: 5.1198
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 6.5767e-04
# Epoch 87: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 1.0000 - loss: 6.5802e-04 - val_accuracy: 0.5142 - val_loss: 5.1344
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 6.4371e-04
# Epoch 88: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 1.0000 - loss: 6.4382e-04 - val_accuracy: 0.5157 - val_loss: 5.1367
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 6.0230e-04
# Epoch 89: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 1.0000 - loss: 6.0292e-04 - val_accuracy: 0.5157 - val_loss: 5.1428
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 5.9771e-04
# Epoch 90: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 1.0000 - loss: 5.9771e-04 - val_accuracy: 0.5187 - val_loss: 5.1572
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 5.7017e-04
# Epoch 91: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 1.0000 - loss: 5.7044e-04 - val_accuracy: 0.5142 - val_loss: 5.1791
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 5.2776e-04
# Epoch 92: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 1.0000 - loss: 5.2852e-04 - val_accuracy: 0.5165 - val_loss: 5.1890
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 5.4767e-04
# Epoch 93: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 5.4749e-04 - val_accuracy: 0.5157 - val_loss: 5.2076
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 5.0692e-04
# Epoch 94: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 5.0729e-04 - val_accuracy: 0.5157 - val_loss: 5.2327
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 4.7977e-04
# Epoch 95: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 4.8039e-04 - val_accuracy: 0.5150 - val_loss: 5.2290
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 4.7742e-04
# Epoch 96: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 4.7763e-04 - val_accuracy: 0.5150 - val_loss: 5.2667
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 4.6612e-04
# Epoch 97: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 4.6626e-04 - val_accuracy: 0.5142 - val_loss: 5.2761
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 4.4863e-04
# Epoch 98: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 1.0000 - loss: 4.4882e-04 - val_accuracy: 0.5165 - val_loss: 5.2812
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 4.2842e-04
# Epoch 99: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 1.0000 - loss: 4.2873e-04 - val_accuracy: 0.5150 - val_loss: 5.2904
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 4.1966e-04
# Epoch 100: val_accuracy did not improve from 0.53223
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - accuracy: 1.0000 - loss: 4.1979e-04 - val_accuracy: 0.5157 - val_loss: 5.2919
# Test loss: 5.291907787322998
# Test accuracy: 0.5157421231269836

# %% [markdown]
# # Xây dựng model dạng sequential

# %%
from tensorflow.keras import layers, models

def main():

    print('simple 3D convolution for action recognition')
    batch = 128
    # training epoch
    epoch = 50
    # directory where videos are stored
    videos= '/kaggle/input/ucf50-latest-version/UCF50'
    # Number of classes
    nclass = 50
    output = 'results_1'
    color  = False
    skip   = True
    depth  = 10

    
    img_rows, img_cols, frames = 32, 32, depth
    channel = 3 if color else 1
    fname_npz = 'dataset_{}_{}_{}.npz'.format(nclass, depth, skip)

    vid3d = Videoto3D(img_rows, img_cols, frames)
    nb_classes = nclass
    if os.path.exists(fname_npz):
        loadeddata = np.load(fname_npz)
        X, Y = loadeddata["X"], loadeddata["Y"]
    else:
        x, y = loaddata(videos, vid3d, nclass,
                        output, color, skip)
        X = x.reshape((x.shape[0], img_rows, img_cols, frames, channel))
        Y = keras.utils.to_categorical(y, nb_classes)

        X = X.astype('float32')
        np.savez(fname_npz, X=X, Y=Y)
        print('Saved dataset to dataset.npz.')
    print('X_shape:{}\nY_shape:{}'.format(X.shape, Y.shape))

    # Define model
    # model = Sequential()


    # model.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 


    # model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
    #     X.shape[1:]), padding='same'))
    # model.add(LeakyReLU(alpha=.001)) 

    ###########################
    input_shape=(32, 32, 10, 1)
    num_classes=50
    model = models.Sequential([
        # Convolutional Layer 1
        layers.Conv3D(32, (3, 3, 3), activation='relu', input_shape=input_shape, padding='same'),
        layers.BatchNormalization(),
        layers.Conv3D(32, (3, 3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling3D((2, 2, 2)),
        layers.Dropout(0.25),
        
        # Convolutional Layer 2
        layers.Conv3D(64, (3, 3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv3D(64, (3, 3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling3D((2, 2, 2)),
        layers.Dropout(0.25),
        
        # Convolutional Layer 3
        layers.Conv3D(128, (3, 3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling3D((2, 2, 2)),
        layers.Dropout(0.25),
        
        # Flatten and Dense Layers
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])

    # Compile model
    model.compile(optimizer='adam',
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])


    model.summary()
    # plot_model(model, show_shapes=True,
    #            to_file=os.path.join(args.output, 'model.png'))

    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=0.2, random_state=43)
    print(X_train.shape)

    ####################

    # 1
    filepath="d_3dcnnmodel_squen-{epoch:02d}-{val_accuracy:.2f}.weights.hd5.keras"
    
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    callbacks_list = [checkpoint]

    # 2 

    config = tf.compat.v1.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.3
    set_session(tf.compat.v1.Session(config=config))

    ###############

    # Train model
    history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=batch,
                        epochs=epoch, verbose=1, shuffle=True, callbacks=callbacks_list)
    
    model.evaluate(X_test, Y_test, verbose=0)
    
    model_json = model.to_json()
    
    if not os.path.isdir(output):
        os.makedirs(output)
    with open(os.path.join(output, 'ucf50_3dcnnmodelsequential.json'), 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights(os.path.join(output, 'ucf50_3dcnnmodelsequential-gpu.weights.h5'))

    loss, acc = model.evaluate(X_test, Y_test, verbose=0)
    
    print('Test loss:', loss)
    print('Test accuracy:', acc)

    plot_history(history, output)
    save_history(history, output)

# %%
if __name__ == '__main__':
    main()
# Out:
# simple 3D convolution for action recognition
# X_shape:(6669, 32, 32, 10, 1)
# Y_shape:(6669, 50)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_26 (Conv3D)              │ (None, 32, 32, 10, 32) │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 32, 32, 10, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_27 (Conv3D)              │ (None, 32, 32, 10, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 32, 32, 10, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_20 (MaxPooling3D) │ (None, 16, 16, 5, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 5, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_28 (Conv3D)              │ (None, 16, 16, 5, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 16, 16, 5, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_29 (Conv3D)              │ (None, 16, 16, 5, 64)  │       110,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 16, 16, 5, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_21 (MaxPooling3D) │ (None, 8, 8, 2, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 2, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_30 (Conv3D)              │ (None, 8, 8, 2, 128)   │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 8, 8, 2, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_22 (MaxPooling3D) │ (None, 4, 4, 1, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 1, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 50)             │        25,650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,493,970 (5.70 MB)
#  Trainable params: 1,492,306 (5.69 MB)
#  Non-trainable params: 1,664 (6.50 KB)
# (5335, 32, 32, 10, 1)
# I0000 00:00:1759247299.917183      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Epoch 1/50
# 2025-09-30 15:48:34.379907: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,32,32,32,10]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:48:35.457133: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.077380968s
# Trying algorithm eng0{} for conv (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,32,32,10]{4,3,2,1,0}, f32[128,32,32,32,10]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.0599 - loss: 4.6396
# 2025-09-30 15:48:50.368443: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[87,32,32,32,10]{4,3,2,1,0}, f32[87,32,32,32,10]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-30 15:48:50.786523: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.418231049s
# Trying algorithm eng0{} for conv (f32[32,32,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[87,32,32,32,10]{4,3,2,1,0}, f32[87,32,32,32,10]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.0608 - loss: 4.6273
# Epoch 1: val_accuracy improved from -inf to 0.04498, saving model to d_3dcnnmodel_squen-01-0.04.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 454ms/step - accuracy: 0.0616 - loss: 4.6156 - val_accuracy: 0.0450 - val_loss: 13.0842
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2261 - loss: 3.1538
# Epoch 2: val_accuracy improved from 0.04498 to 0.24138, saving model to d_3dcnnmodel_squen-02-0.24.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.2267 - loss: 3.1499 - val_accuracy: 0.2414 - val_loss: 2.8783
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3549 - loss: 2.3916
# Epoch 3: val_accuracy improved from 0.24138 to 0.33733, saving model to d_3dcnnmodel_squen-03-0.34.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.3554 - loss: 2.3900 - val_accuracy: 0.3373 - val_loss: 2.4710
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4769 - loss: 1.8979
# Epoch 4: val_accuracy improved from 0.33733 to 0.37631, saving model to d_3dcnnmodel_squen-04-0.38.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.4770 - loss: 1.8974 - val_accuracy: 0.3763 - val_loss: 2.4116
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5598 - loss: 1.5536
# Epoch 5: val_accuracy improved from 0.37631 to 0.55172, saving model to d_3dcnnmodel_squen-05-0.55.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.5600 - loss: 1.5530 - val_accuracy: 0.5517 - val_loss: 1.7216
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6305 - loss: 1.3168
# Epoch 6: val_accuracy did not improve from 0.55172
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.6307 - loss: 1.3157 - val_accuracy: 0.5472 - val_loss: 1.6710
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7020 - loss: 1.0388
# Epoch 7: val_accuracy improved from 0.55172 to 0.62744, saving model to d_3dcnnmodel_squen-07-0.63.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7020 - loss: 1.0389 - val_accuracy: 0.6274 - val_loss: 1.3777
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7623 - loss: 0.8584
# Epoch 8: val_accuracy improved from 0.62744 to 0.65367, saving model to d_3dcnnmodel_squen-08-0.65.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.7622 - loss: 0.8584 - val_accuracy: 0.6537 - val_loss: 1.3375
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8035 - loss: 0.7040
# Epoch 9: val_accuracy improved from 0.65367 to 0.68441, saving model to d_3dcnnmodel_squen-09-0.68.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.8032 - loss: 0.7044 - val_accuracy: 0.6844 - val_loss: 1.2105
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8372 - loss: 0.5924
# Epoch 10: val_accuracy improved from 0.68441 to 0.74738, saving model to d_3dcnnmodel_squen-10-0.75.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8371 - loss: 0.5925 - val_accuracy: 0.7474 - val_loss: 0.9411
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8635 - loss: 0.4919
# Epoch 11: val_accuracy did not improve from 0.74738
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.8633 - loss: 0.4924 - val_accuracy: 0.7136 - val_loss: 1.1346
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8737 - loss: 0.4509
# Epoch 12: val_accuracy did not improve from 0.74738
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.8738 - loss: 0.4508 - val_accuracy: 0.7339 - val_loss: 1.0221
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8862 - loss: 0.3870
# Epoch 13: val_accuracy improved from 0.74738 to 0.75262, saving model to d_3dcnnmodel_squen-13-0.75.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8863 - loss: 0.3870 - val_accuracy: 0.7526 - val_loss: 0.9643
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9074 - loss: 0.3405
# Epoch 14: val_accuracy improved from 0.75262 to 0.77136, saving model to d_3dcnnmodel_squen-14-0.77.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9075 - loss: 0.3403 - val_accuracy: 0.7714 - val_loss: 0.8885
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9234 - loss: 0.2828
# Epoch 15: val_accuracy improved from 0.77136 to 0.78861, saving model to d_3dcnnmodel_squen-15-0.79.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9233 - loss: 0.2830 - val_accuracy: 0.7886 - val_loss: 0.7939
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9422 - loss: 0.2326
# Epoch 16: val_accuracy improved from 0.78861 to 0.80510, saving model to d_3dcnnmodel_squen-16-0.81.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9421 - loss: 0.2327 - val_accuracy: 0.8051 - val_loss: 0.7535
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9390 - loss: 0.2260
# Epoch 17: val_accuracy did not improve from 0.80510
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9390 - loss: 0.2259 - val_accuracy: 0.7924 - val_loss: 0.7413
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9512 - loss: 0.1713
# Epoch 18: val_accuracy improved from 0.80510 to 0.83133, saving model to d_3dcnnmodel_squen-18-0.83.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9511 - loss: 0.1716 - val_accuracy: 0.8313 - val_loss: 0.6759
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9634 - loss: 0.1596
# Epoch 19: val_accuracy did not improve from 0.83133
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9634 - loss: 0.1597 - val_accuracy: 0.8238 - val_loss: 0.6468
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9713 - loss: 0.1217
# Epoch 20: val_accuracy did not improve from 0.83133
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9713 - loss: 0.1219 - val_accuracy: 0.8186 - val_loss: 0.7259
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9730 - loss: 0.1217
# Epoch 21: val_accuracy improved from 0.83133 to 0.83208, saving model to d_3dcnnmodel_squen-21-0.83.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9729 - loss: 0.1220 - val_accuracy: 0.8321 - val_loss: 0.6632
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9634 - loss: 0.1341
# Epoch 22: val_accuracy did not improve from 0.83208
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9634 - loss: 0.1340 - val_accuracy: 0.8306 - val_loss: 0.6588
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9700 - loss: 0.1105
# Epoch 23: val_accuracy did not improve from 0.83208
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9700 - loss: 0.1105 - val_accuracy: 0.8231 - val_loss: 0.6668
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9733 - loss: 0.1033
# Epoch 24: val_accuracy did not improve from 0.83208
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9732 - loss: 0.1034 - val_accuracy: 0.7759 - val_loss: 0.8279
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9746 - loss: 0.1002
# Epoch 25: val_accuracy improved from 0.83208 to 0.83508, saving model to d_3dcnnmodel_squen-25-0.84.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9746 - loss: 0.1002 - val_accuracy: 0.8351 - val_loss: 0.6294
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9799 - loss: 0.0867
# Epoch 26: val_accuracy did not improve from 0.83508
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9799 - loss: 0.0867 - val_accuracy: 0.8313 - val_loss: 0.6503
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9844 - loss: 0.0713
# Epoch 27: val_accuracy improved from 0.83508 to 0.84033, saving model to d_3dcnnmodel_squen-27-0.84.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9843 - loss: 0.0714 - val_accuracy: 0.8403 - val_loss: 0.6617
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9807 - loss: 0.0743
# Epoch 28: val_accuracy improved from 0.84033 to 0.84183, saving model to d_3dcnnmodel_squen-28-0.84.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9807 - loss: 0.0743 - val_accuracy: 0.8418 - val_loss: 0.6429
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9803 - loss: 0.0801
# Epoch 29: val_accuracy did not improve from 0.84183
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9803 - loss: 0.0799 - val_accuracy: 0.8261 - val_loss: 0.7050
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9813 - loss: 0.0699
# Epoch 30: val_accuracy did not improve from 0.84183
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9813 - loss: 0.0700 - val_accuracy: 0.8276 - val_loss: 0.6601
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9859 - loss: 0.0597
# Epoch 31: val_accuracy did not improve from 0.84183
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9859 - loss: 0.0598 - val_accuracy: 0.7886 - val_loss: 0.8746
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9845 - loss: 0.0629
# Epoch 32: val_accuracy improved from 0.84183 to 0.84408, saving model to d_3dcnnmodel_squen-32-0.84.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9845 - loss: 0.0629 - val_accuracy: 0.8441 - val_loss: 0.6148
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9878 - loss: 0.0522
# Epoch 33: val_accuracy improved from 0.84408 to 0.85082, saving model to d_3dcnnmodel_squen-33-0.85.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9877 - loss: 0.0523 - val_accuracy: 0.8508 - val_loss: 0.6552
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9818 - loss: 0.0645
# Epoch 34: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9818 - loss: 0.0646 - val_accuracy: 0.7946 - val_loss: 0.8690
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9835 - loss: 0.0683
# Epoch 35: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9835 - loss: 0.0683 - val_accuracy: 0.8231 - val_loss: 0.7320
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9839 - loss: 0.0661
# Epoch 36: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9838 - loss: 0.0661 - val_accuracy: 0.8253 - val_loss: 0.7537
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9789 - loss: 0.0706
# Epoch 37: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9789 - loss: 0.0705 - val_accuracy: 0.8373 - val_loss: 0.6874
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9875 - loss: 0.0511
# Epoch 38: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9875 - loss: 0.0511 - val_accuracy: 0.8051 - val_loss: 0.8710
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9870 - loss: 0.0508
# Epoch 39: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9870 - loss: 0.0509 - val_accuracy: 0.8306 - val_loss: 0.7231
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9804 - loss: 0.0603
# Epoch 40: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9804 - loss: 0.0604 - val_accuracy: 0.8231 - val_loss: 0.7408
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9833 - loss: 0.0534
# Epoch 41: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9832 - loss: 0.0536 - val_accuracy: 0.8193 - val_loss: 0.7606
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9847 - loss: 0.0520
# Epoch 42: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.9846 - loss: 0.0522 - val_accuracy: 0.8163 - val_loss: 0.7913
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9862 - loss: 0.0541
# Epoch 43: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9861 - loss: 0.0542 - val_accuracy: 0.8193 - val_loss: 0.7543
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9864 - loss: 0.0528
# Epoch 44: val_accuracy did not improve from 0.85082
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9864 - loss: 0.0528 - val_accuracy: 0.7999 - val_loss: 0.9224
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9862 - loss: 0.0444
# Epoch 45: val_accuracy improved from 0.85082 to 0.85532, saving model to d_3dcnnmodel_squen-45-0.86.weights.hd5.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9862 - loss: 0.0444 - val_accuracy: 0.8553 - val_loss: 0.6603
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9891 - loss: 0.0382
# Epoch 46: val_accuracy did not improve from 0.85532
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9890 - loss: 0.0383 - val_accuracy: 0.8501 - val_loss: 0.6485
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9900 - loss: 0.0397
# Epoch 47: val_accuracy did not improve from 0.85532
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9900 - loss: 0.0397 - val_accuracy: 0.8516 - val_loss: 0.6540
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9866 - loss: 0.0463
# Epoch 48: val_accuracy did not improve from 0.85532
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9866 - loss: 0.0463 - val_accuracy: 0.8343 - val_loss: 0.7014
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9921 - loss: 0.0334
# Epoch 49: val_accuracy did not improve from 0.85532
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9921 - loss: 0.0336 - val_accuracy: 0.8336 - val_loss: 0.7572
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9904 - loss: 0.0367
# Epoch 50: val_accuracy did not improve from 0.85532
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9904 - loss: 0.0368 - val_accuracy: 0.8426 - val_loss: 0.6527
# Test loss: 0.6527301669120789
# Test accuracy: 0.8425787091255188

# %% [markdown]
# # PHẦN 2

# %%
# (Tùy chọn) Cài đặt thư viện nếu môi trường thiếu.
# Bạn có thể comment nếu đã có sẵn.
# !pip install opencv-python tqdm

import os
import math
import json
import time
import random
import shutil
from pathlib import Path
from dataclasses import dataclass, asdict

import cv2
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import torchvision
from torchvision import transforms
import torchvision.models as models

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # Configuration

# %%
@dataclass
class Config:
    # Đường dẫn & IO
    DATA_ROOT: str = "/kaggle/input/ucf50-latest-version/UCF50"   # Sửa theo nơi lưu dữ liệu (VD: local)
    OUTPUT_DIR: str = "./outputs_ucf50_fusion"
    LABELS_JSON: str = "labels_map.json"
    FLOW_CACHE_DIR: str = "./flow_cache"           # Cache *.npy cho optical flow (tùy chọn)

    # Dataloader
    IMG_SIZE: int = 224
    BATCH_SIZE: int = 16
    NUM_WORKERS: int = 2
    VAL_SPLIT: float = 0.2
    SEED: int = 1337

    # Lấy mẫu video
    NUM_SEGMENTS: int = 1          # số frame mẫu (cho RGB). Two-Stream 2D thường 1 frame/clip
    FLOW_STACK: int = 5            # số cặp (u,v) liên tiếp => 2*FLOW_STACK kênh
    FLOW_METHOD: str = "farneback" # "farneback" | "tvl1"
    FLOW_PRECOMPUTE: bool = True   # bật cache optical flow ra đĩa

    # Huấn luyện
    NUM_EPOCHS: int = 10
    LEARNING_RATE: float = 1e-3
    WEIGHT_DECAY: float = 1e-4
    SCHEDULER: str = "cosine"      # "cosine" | "step" | "plateau" | "none"
    STEP_SIZE: int = 5
    GAMMA: float = 0.1
    T_MAX: int = 10                # cho CosineAnnealingLR
    EARLY_STOP_PATIENCE: int = 5

    # Fusion
    FUSION: str = "late"           # "late" | "early_feature" | "early_channel"
    LATE_FUSION_WEIGHTS: tuple = (0.5, 0.5)  # (w_rgb, w_flow)
    # Nếu early_channel: in_channels = 3 + 2*FLOW_STACK
    # Nếu early_feature: concat features: [feat_rgb ; feat_flow]

    # Lưu & Log
    SAVE_BEST: bool = True
    BEST_MODEL_PATH: str = "best_model.pth"
    LOG_JSON: str = "train_log.json"

cfg = Config()

# Tạo thư mục xuất
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
os.makedirs(cfg.FLOW_CACHE_DIR, exist_ok=True)

# Cố định seed cho tái lập
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(cfg.SEED)
print(cfg)
# Out:
# Config(DATA_ROOT='/kaggle/input/ucf50-latest-version/UCF50', OUTPUT_DIR='./outputs_ucf50_fusion', LABELS_JSON='labels_map.json', FLOW_CACHE_DIR='./flow_cache', IMG_SIZE=224, BATCH_SIZE=16, NUM_WORKERS=2, VAL_SPLIT=0.2, SEED=1337, NUM_SEGMENTS=1, FLOW_STACK=5, FLOW_METHOD='farneback', FLOW_PRECOMPUTE=True, NUM_EPOCHS=10, LEARNING_RATE=0.001, WEIGHT_DECAY=0.0001, SCHEDULER='cosine', STEP_SIZE=5, GAMMA=0.1, T_MAX=10, EARLY_STOP_PATIENCE=5, FUSION='late', LATE_FUSION_WEIGHTS=(0.5, 0.5), SAVE_BEST=True, BEST_MODEL_PATH='best_model.pth', LOG_JSON='train_log.json')

# %% [markdown]
# # Processing_data

# %%
def scan_ucf50(root: str):
    root = Path(root)
    classes = sorted([p.name for p in root.iterdir() if p.is_dir()])
    items = []
    for ci, cname in enumerate(classes):
        for v in (root/cname).glob("*.avi"):
            items.append({"path": str(v), "label_name": cname, "label": ci})
    return classes, items

classes, items = scan_ucf50(cfg.DATA_ROOT)
num_classes = len(classes)
print(f"Found {len(items)} videos across {num_classes} classes.")

# Lưu nhãn
labels_map = {i: c for i, c in enumerate(classes)}
with open(os.path.join(cfg.OUTPUT_DIR, cfg.LABELS_JSON), "w", encoding="utf-8") as f:
    json.dump(labels_map, f, ensure_ascii=False, indent=2)

# Stratified split theo lớp
from collections import defaultdict
by_class = defaultdict(list)
for it in items:
    by_class[it["label"]].append(it)

train_list, val_list = [], []
for k, vids in by_class.items():
    n = len(vids)
    idx = list(range(n))
    random.shuffle(idx)
    cut = int(n * (1.0 - cfg.VAL_SPLIT))
    for j in idx[:cut]:
        train_list.append(vids[j])
    for j in idx[cut:]:
        val_list.append(vids[j])

print(f"Train videos: {len(train_list)}, Val videos: {len(val_list)}")
# Out:
# Found 6669 videos across 50 classes.
# Train videos: 5316, Val videos: 1353

# %%
def read_video_frames(path, target_indices, resize_hw=None):
    '''Đọc một số frame theo chỉ số trong video. Trả về list ảnh BGR (np.uint8).'''
    cap = cv2.VideoCapture(path)
    frames = []
    if not cap.isOpened():
        cap.release()
        raise RuntimeError(f"Cannot open video: {path}")
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    for ti in target_indices:
        idx = min(max(int(ti), 0), max(total-1, 0))
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ok, frame = cap.read()
        if not ok:
            ok2, frame2 = cap.read()
            if not ok2:
                frame = np.zeros((resize_hw[0], resize_hw[1], 3), dtype=np.uint8) if resize_hw else None
            else:
                frame = frame2
        if resize_hw is not None and frame is not None:
            frame = cv2.resize(frame, (resize_hw[1], resize_hw[0]), interpolation=cv2.INTER_LINEAR)
        frames.append(frame)
    cap.release()
    return frames

def compute_flow_pair(prev_gray, next_gray, method="farneback"):
    if method == "farneback":
        flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray,
                                            None, 0.5, 3, 15, 3, 5, 1.2, 0)
        return flow  # HxWx2 (u,v)
    elif method == "tvl1":
        tvl1 = cv2.optflow.DualTVL1OpticalFlow_create()
        flow = tvl1.calc(prev_gray, next_gray, None)
        return flow
    else:
        raise ValueError("FLOW_METHOD must be 'farneback' or 'tvl1'")

def flow_to_uv_stack(frames_gray, flow_stack=5, method="farneback"):
    '''Tính (u,v) cho flow_stack cặp khung hình liên tiếp quanh frame trung tâm.
       Trả về array shape (2*flow_stack, H, W), dtype float32.'''
    T = len(frames_gray)
    if T < flow_stack + 1:
        while len(frames_gray) < flow_stack + 1:
            frames_gray.append(frames_gray[-1])
        T = len(frames_gray)
    uv_list = []
    for i in range(flow_stack):
        f0 = frames_gray[i]
        f1 = frames_gray[i+1]
        flow = compute_flow_pair(f0, f1, method=method)  # HxWx2
        u, v = flow[..., 0], flow[..., 1]
        uv_list.append(u.astype(np.float32))
        uv_list.append(v.astype(np.float32))
    uv = np.stack(uv_list, axis=0)  # (2*flow_stack, H, W)
    uv = np.clip(uv, -20.0, 20.0) / 20.0  # [-1,1]
    return uv

def load_or_compute_flow_stack(video_path, center_idx, resize_hw, flow_stack, method, cache_dir):
    '''Tải từ cache hoặc tính flow quanh center_idx. Cache theo tên file.'''
    from pathlib import Path
    key = f"{Path(video_path).stem}_f{center_idx}_s{flow_stack}_{method}_{resize_hw[0]}x{resize_hw[1]}.npy"
    cache_path = Path(cache_dir)/key
    if cache_path.exists():
        return np.load(str(cache_path))
    frame_indices = [center_idx + i for i in range(flow_stack+1)]
    frames = read_video_frames(video_path, frame_indices, resize_hw)
    grays = [cv2.cvtColor(f, cv2.COLOR_BGR2GRAY) for f in frames]
    uv = flow_to_uv_stack(grays, flow_stack=flow_stack, method=method)
    # np.save(str(cache_path), uv)
    return uv

# %%
class UCF50TwoStreamDataset(Dataset):
    def __init__(self, items, img_size=224, num_segments=1, flow_stack=5,
                 flow_method="farneback", flow_cache_dir=None, mode="train"):
        self.items = items
        self.H = img_size
        self.W = img_size
        self.num_segments = num_segments
        self.flow_stack = flow_stack
        self.flow_method = flow_method
        self.flow_cache_dir = flow_cache_dir
        self.mode = mode

        self.rgb_train_tf = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((self.H, self.W)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])
        self.rgb_val_tf = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((self.H, self.W)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

        self.to_tensor = transforms.ToTensor()

    def __len__(self):
        return len(self.items)

    def _sample_center(self, vpath):
        cap = cv2.VideoCapture(vpath)
        if not cap.isOpened():
            return 0, 1
        total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        cap.release()
        if total <= 1:
            return 0, 1
        ci = random.randint(1, max(total-2, 1))
        return ci, total

    def __getitem__(self, idx):
        rec = self.items[idx]
        vpath = rec["path"]
        label = rec["label"]

        center_idx, total = self._sample_center(vpath)

        rgb_frame = read_video_frames(vpath, [center_idx], resize_hw=(self.H, self.W))[0]  # BGR
        rgb = cv2.cvtColor(rgb_frame, cv2.COLOR_BGR2RGB)
        if self.mode == "train":
            rgb_t = self.rgb_train_tf(rgb)
        else:
            rgb_t = self.rgb_val_tf(rgb)

        if self.flow_cache_dir is not None:
            uv = load_or_compute_flow_stack(
                vpath, center_idx, (self.H, self.W),
                self.flow_stack, self.flow_method, self.flow_cache_dir
            )
        else:
            frames = read_video_frames(vpath, [center_idx + i for i in range(self.flow_stack+1)],
                                       resize_hw=(self.H, self.W))
            grays = [cv2.cvtColor(f, cv2.COLOR_BGR2GRAY) for f in frames]
            uv = flow_to_uv_stack(grays, self.flow_stack, self.flow_method)
        flow_t = torch.from_numpy(uv)  # (2*flow_stack, H, W)

        return rgb_t, flow_t, label

# %%
train_ds = UCF50TwoStreamDataset(
    train_list, img_size=cfg.IMG_SIZE, num_segments=cfg.NUM_SEGMENTS,
    flow_stack=cfg.FLOW_STACK, flow_method=cfg.FLOW_METHOD,
    flow_cache_dir=(cfg.FLOW_CACHE_DIR if cfg.FLOW_PRECOMPUTE else None),
    mode="train"
)
val_ds = UCF50TwoStreamDataset(
    val_list, img_size=cfg.IMG_SIZE, num_segments=cfg.NUM_SEGMENTS,
    flow_stack=cfg.FLOW_STACK, flow_method=cfg.FLOW_METHOD,
    flow_cache_dir=(cfg.FLOW_CACHE_DIR if cfg.FLOW_PRECOMPUTE else None),
    mode="val"
)

train_loader = DataLoader(train_ds, batch_size=cfg.BATCH_SIZE, shuffle=True,
                          num_workers=cfg.NUM_WORKERS, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size=cfg.BATCH_SIZE, shuffle=False,
                        num_workers=cfg.NUM_WORKERS, pin_memory=True)

len(train_ds), len(val_ds)
# Out:
# (5316, 1353)

# %% [markdown]
# # Types of Fusion

# %% [markdown]
# ## Thay backbone Resnet18 -> Mobile Net v3 small

# %%
# def inflate_conv1_weight(conv1: nn.Conv2d, new_in_channels: int):
#     '''Mở rộng conv1 để nhận nhiều kênh > 3 bằng cách lặp/avg trọng số ban đầu.'''
#     out_c, in_c, kh, kw = old_w.shape
#     if new_in_channels == in_c:
#         return conv1
#     new_w = torch.zeros((out_c, new_in_channels, kh, kw))
#     for oc in range(out_c):
#         for ic in range(new_in_channels):
#             new_w[oc, ic] = old_w[oc, ic % in_c]
#     conv1.in_channels = new_in_channels
#     conv1.weight = nn.Parameter(new_w)
#     return conv1

# class EarlyChannelMobileNet(nn.Module):
#     '''Early-Channel Fusion: ghép RGB + Flow theo kênh => một backbone duy nhất.'''
#     def __init__(self, num_classes, in_channels):
#         super().__init__()
#         self.backbone = mobilenet_v3_small(weights='IMAGENET1K_V1')
#         self.backbone.conv1 = inflate_conv1_weight(self.backbone.conv1, in_channels)
#         in_feat = self.backbone.fc.in_features
#         self.backbone.fc = nn.Linear(in_feat, num_classes)

#     def forward(self, x):  # x: (B, C, H, W)
#         return self.backbone(x)

# class TwoBackboneEarlyFeature(nn.Module):
#     '''Early-Feature Fusion: 2 backbone riêng -> concat features -> classifier.'''
#     def __init__(self, num_classes, flow_in_channels):
#         super().__init__()
#         self.rgb_net = mobilenet_v3_small(weights='IMAGENET1K_V1')
#         self.flow_net = mobilenet_v3_small(weights='IMAGENET1K_V1')
#         self.flow_net.conv1 = inflate_conv1_weight(self.flow_net.conv1, flow_in_channels)
#         self.rgb_net.fc = nn.Identity()
#         self.flow_net.fc = nn.Identity()
#         in_feat = 512 + 512
#         self.fc = nn.Linear(in_feat, num_classes)

#     def forward(self, rgb, flow):
#         fr = self.rgb_net(rgb)   # (B,512)
#         ff = self.flow_net(flow) # (B,512)
#         f = torch.cat([fr, ff], dim=1)
#         logits = self.fc(f)
#         return logits

# class LateFusionModel(nn.Module):
#     '''Late Fusion: 2 backbone riêng -> logits riêng -> trộn theo trọng số.'''
#     def __init__(self, num_classes, flow_in_channels, w_rgb=0.5, w_flow=0.5):
#         super().__init__()
#         self.rgb_net = mobilenet_v3_small(weights='IMAGENET1K_V1')
#         self.flow_net = mobilenet_v3_small(weights='IMAGENET1K_V1')
#         self.flow_net.conv1 = inflate_conv1_weight(self.flow_net.conv1, flow_in_channels)
#         self.rgb_head = nn.Linear(self.rgb_net.fc.in_features, num_classes)
#         self.flow_head = nn.Linear(self.flow_net.fc.in_features, num_classes)
#         self.w_rgb = w_rgb
#         self.w_flow = w_flow
#         self.rgb_net.fc = nn.Identity()
#         self.flow_net.fc = nn.Identity()

#     def forward(self, rgb, flow):
#         fr = self.rgb_net(rgb)    # (B,512)
#         ff = self.flow_net(flow)  # (B,512)
#         lr = self.rgb_head(fr)    # (B,C)
#         lf = self.flow_head(ff)   # (B,C)
#         logits = self.w_rgb * lr + self.w_flow * lf
#         return logits, lr, lf


def inflate_conv_weight(conv: nn.Conv2d, new_in_channels: int):
    '''Mở rộng lớp Conv2d để nhận nhiều kênh > 3 bằng cách lặp/avg trọng số ban đầu.'''
    old_w = conv.weight.data  # (out_c, in_c, k, k)
    out_c, in_c, kh, kw = old_w.shape
    if new_in_channels == in_c:
        return conv
    new_w = torch.zeros((out_c, new_in_channels, kh, kw))
    for oc in range(out_c):
        for ic in range(new_in_channels):
            new_w[oc, ic] = old_w[oc, ic % in_c]
    new_conv = nn.Conv2d(new_in_channels, out_c, kernel_size=(kh, kw), 
                         stride=conv.stride, padding=conv.padding, bias=conv.bias is not None)
    new_conv.weight = nn.Parameter(new_w)
    if conv.bias is not None:
        new_conv.bias = nn.Parameter(conv.bias.data.clone())
    return new_conv

class EarlyChannelMobileNet(nn.Module):
    '''Early-Channel Fusion: ghép RGB + Flow theo kênh => một backbone duy nhất.'''
    def __init__(self, num_classes, in_channels):
        super().__init__()
        self.backbone = models.mobilenet_v3_small(weights='IMAGENET1K_V1')
        self.backbone.features[0][0] = inflate_conv_weight(self.backbone.features[0][0], in_channels)
        in_feat = self.backbone.classifier[-1].in_features
        self.backbone.classifier[-1] = nn.Linear(in_feat, num_classes)

    def forward(self, x):  # x: (B, C, H, W)
        return self.backbone(x)

class TwoBackboneEarlyFeature(nn.Module):
    '''Early-Feature Fusion: 2 backbone riêng -> concat features -> classifier.'''
    def __init__(self, num_classes, flow_in_channels):
        super().__init__()
        self.rgb_net = models.mobilenet_v3_small(weights='IMAGENET1K_V1')
        self.flow_net = models.mobilenet_v3_small(weights='IMAGENET1K_V1')
        self.flow_net.features[0][0] = inflate_conv_weight(self.flow_net.features[0][0], flow_in_channels)
        self.rgb_net.classifier = nn.Identity()
        self.flow_net.classifier = nn.Identity()
        in_feat = 576 + 576
        self.fc = nn.Linear(in_feat, num_classes)

    def forward(self, rgb, flow):
        fr = self.rgb_net(rgb)   # (B, 576)
        ff = self.flow_net(flow) # (B, 576)
        f = torch.cat([fr, ff], dim=1)
        logits = self.fc(f)
        return logits

class LateFusionModel(nn.Module):
    '''Late Fusion: 2 backbone riêng -> logits riêng -> trộn theo trọng số.'''
    def __init__(self, num_classes, flow_in_channels, w_rgb=0.5, w_flow=0.5):
        super().__init__()
        self.rgb_net = models.mobilenet_v3_small(weights='IMAGENET1K_V1')
        self.flow_net = models.mobilenet_v3_small(weights='IMAGENET1K_V1')
        # Điều chỉnh lớp convolution đầu tiên của flow_net
        self.flow_net.features[0][0] = inflate_conv_weight(self.flow_net.features[0][0], flow_in_channels)
        # Lấy số đặc trưng từ classifier (MobileNetV3-Small có in_features=576)
        in_feat = 576  # Hard-coded vì MobileNetV3-Small luôn có 576
        self.rgb_head = nn.Linear(in_feat, num_classes)
        self.flow_head = nn.Linear(in_feat, num_classes)
        self.w_rgb = w_rgb
        self.w_flow = w_flow
        # Loại bỏ classifier gốc
        self.rgb_net.classifier = nn.Identity()
        self.flow_net.classifier = nn.Identity()

    def forward(self, rgb, flow):
        fr = self.rgb_net(rgb)    # (B, 576)
        ff = self.flow_net(flow)  # (B, 576)
        lr = self.rgb_head(fr)    # (B, num_classes)
        lf = self.flow_head(ff)   # (B, num_classes)
        logits = self.w_rgb * lr + self.w_flow * lf
        return logits, lr, lf

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

flow_in_ch = 2 * cfg.FLOW_STACK

if cfg.FUSION == "early_channel":
    model = EarlyChannelMobileNet(num_classes=num_classes, in_channels=3 + flow_in_ch).to(device)
elif cfg.FUSION == "early_feature":
    model = TwoBackboneEarlyFeature(num_classes=num_classes, flow_in_channels=flow_in_ch).to(device)
elif cfg.FUSION == "late":
    w_rgb, w_flow = cfg.LATE_FUSION_WEIGHTS
    model = LateFusionModel(num_classes=num_classes, flow_in_channels=flow_in_ch,
                            w_rgb=w_rgb, w_flow=w_flow).to(device)
else:
    raise ValueError("cfg.FUSION must be one of: early_channel | early_feature | late")

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.LEARNING_RATE, weight_decay=cfg.WEIGHT_DECAY)
if cfg.SCHEDULER == "cosine":
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.T_MAX)
elif cfg.SCHEDULER == "step":
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=cfg.STEP_SIZE, gamma=cfg.GAMMA)
elif cfg.SCHEDULER == "plateau":
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=2, factor=0.5)
else:
    scheduler = None

criterion = nn.CrossEntropyLoss()

class EarlyStopper:
    def __init__(self, patience=5):
        self.patience = patience
        self.best = -1.0
        self.count = 0
    def step(self, metric):
        if metric > self.best:
            self.best = metric
            self.count = 0
            return True
        else:
            self.count += 1
            return False
    def should_stop(self):
        return self.count >= self.patience

early_stopper = EarlyStopper(cfg.EARLY_STOP_PATIENCE)
# Out:
# Device: cuda

# %%
def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0
    for rgb, flow, y in tqdm(loader, desc="Train", leave=False):
        rgb = rgb.to(device)
        flow = flow.to(device)
        y = y.to(device)

        optimizer.zero_grad()
        if isinstance(model, EarlyChannelMobileNet):
            x = torch.cat([rgb, flow], dim=1)  # (B, 3+2*flow_stack, H, W)
            logits = model(x)
        elif isinstance(model, TwoBackboneEarlyFeature):
            logits = model(rgb, flow)
        elif isinstance(model, LateFusionModel):
            logits, _, _ = model(rgb, flow)
        else:
            raise RuntimeError("Unknown model type")

        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            pred = logits.argmax(dim=1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)

    return loss_sum/total, correct/total

@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    total, correct, loss_sum = 0, 0, 0.0
    all_y, all_pred = [], []
    for rgb, flow, y in tqdm(loader, desc="Val", leave=False):
        rgb = rgb.to(device)
        flow = flow.to(device)
        y = y.to(device)
        if isinstance(model, EarlyChannelMobileNet):
            x = torch.cat([rgb, flow], dim=1)
            logits = model(x)
        elif isinstance(model, TwoBackboneEarlyFeature):
            logits = model(rgb, flow)
        elif isinstance(model, LateFusionModel):
            logits, _, _ = model(rgb, flow)
        else:
            raise RuntimeError("Unknown model type")

        loss = criterion(logits, y)
        pred = logits.argmax(dim=1)

        correct += (pred == y).sum().item()
        total += y.size(0)
        loss_sum += loss.item() * y.size(0)

        all_y.extend(y.cpu().numpy().tolist())
        all_pred.extend(pred.cpu().numpy().tolist())

    acc = correct/total if total > 0 else 0.0
    return loss_sum/max(total,1), acc, np.array(all_y), np.array(all_pred)

# %%
best_acc = -1.0
log_hist = []

for epoch in range(1, cfg.NUM_EPOCHS+1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_loss, val_acc, y_true, y_pred = evaluate(model, val_loader, criterion, device)

    if cfg.SCHEDULER == "plateau":
        scheduler.step(val_acc)
    elif cfg.SCHEDULER in ["cosine", "step"] and scheduler is not None:
        scheduler.step()

    rec = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_acc": train_acc,
        "val_loss": val_loss,
        "val_acc": val_acc,
        "lr": optimizer.param_groups[0]["lr"],
        "time_sec": round(time.time()-t0, 2),
    }
    log_hist.append(rec)
    print(f"[Epoch {epoch:02d}] "
          f"train_loss={train_loss:.4f} acc={train_acc:.4f} | "
          f"val_loss={val_loss:.4f} acc={val_acc:.4f} | lr={rec['lr']:.2e} | "
          f"time={rec['time_sec']}s")

    improved = val_acc > best_acc
    if improved and cfg.SAVE_BEST:
        best_acc = val_acc
        # torch.save(model.state_dict(), os.path.join(cfg.OUTPUT_DIR, cfg.BEST_MODEL_PATH))
        # with open(os.path.join(cfg.OUTPUT_DIR, "best_epoch.txt"), "w") as f:
        #     f.write(f"best_epoch={epoch}\nval_acc={val_acc:.4f}\n")

    if early_stopper.step(val_acc) is False and early_stopper.should_stop():
        print("Early stopping triggered.")
        break

# with open(os.path.join(cfg.OUTPUT_DIR, cfg.LOG_JSON), "w") as f:
#     json.dump(log_hist, f, indent=2)

print("Training done. Best val acc:", best_acc)
# Out:
# [Epoch 01] train_loss=0.7190 acc=0.7912 | val_loss=0.6714 acc=0.7975 | lr=9.05e-04 | time=490.92s
# [Epoch 02] train_loss=0.4506 acc=0.8681 | val_loss=0.5652 acc=0.8411 | lr=7.94e-04 | time=491.63s
# [Epoch 03] train_loss=0.3078 acc=0.9093 | val_loss=0.4882 acc=0.8477 | lr=6.55e-04 | time=497.59s
# [Epoch 04] train_loss=0.2093 acc=0.9398 | val_loss=0.2677 acc=0.9165 | lr=5.00e-04 | time=504.93s
# [Epoch 05] train_loss=0.1669 acc=0.9505 | val_loss=0.1719 acc=0.9549 | lr=3.45e-04 | time=503.4s
# [Epoch 06] train_loss=0.1069 acc=0.9701 | val_loss=0.1968 acc=0.9424 | lr=2.06e-04 | time=492.73s
# [Epoch 07] train_loss=0.0956 acc=0.9740 | val_loss=0.1023 acc=0.9734 | lr=9.55e-05 | time=486.91s
# [Epoch 08] train_loss=0.0628 acc=0.9853 | val_loss=0.1007 acc=0.9719 | lr=2.45e-05 | time=483.04s
# [Epoch 09] train_loss=0.0597 acc=0.9850 | val_loss=0.0948 acc=0.9704 | lr=0.00e+00 | time=485.82s
# [Epoch 10] train_loss=0.0631 acc=0.9844 | val_loss=0.1029 acc=0.9704 | lr=2.45e-05 | time=486.9s
# Training done. Best val acc: 0.9733924611973392

# %%
@torch.no_grad()
def predict_single_video(model, video_path, cfg):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.eval()
    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) if cap.isOpened() else 2
    cap.release()
    ci = min(max(total//2, 1), max(total-2, 1))

    rgb_frame = read_video_frames(video_path, [ci], resize_hw=(cfg.IMG_SIZE, cfg.IMG_SIZE))[0]
    rgb = cv2.cvtColor(rgb_frame, cv2.COLOR_BGR2RGB)
    tf = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((cfg.IMG_SIZE, cfg.IMG_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ])
    rgb_t = tf(rgb).unsqueeze(0).to(device)

    uv = load_or_compute_flow_stack(
        video_path, ci, (cfg.IMG_SIZE, cfg.IMG_SIZE), cfg.FLOW_STACK, cfg.FLOW_METHOD, cfg.FLOW_CACHE_DIR
    )
    flow_t = torch.from_numpy(uv).unsqueeze(0).to(device)  # (1,2*stack,H,W)

    if isinstance(model, EarlyChannelMobileNet):
        x = torch.cat([rgb_t, flow_t], dim=1)
        logits = model(x)
    elif isinstance(model, TwoBackboneEarlyFeature):
        logits = model(rgb_t, flow_t)
    elif isinstance(model, LateFusionModel):
        logits, _, _ = model(rgb_t, flow_t)

    prob = F.softmax(logits, dim=1)[0].cpu().numpy()
    pred_idx = int(np.argmax(prob))
    return pred_idx, prob

# Ví dụ sử dụng (sau khi train):
pred_idx, prob = predict_single_video(model, "/kaggle/input/ucf50-latest-version/UCF50/Basketball/v_Basketball_g01_c01.avi", cfg)
print("Dự đoán:", classes[pred_idx])
# Out:
# Dự đoán: Basketball
