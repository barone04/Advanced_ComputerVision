# %% [markdown]
# # DCGAN trên CIFAR10
#
# Notebook này huấn luyện DCGAN trên CIFAR10 (ảnh màu 32×32, resize lên 64×64).

# %%
# !pip install torch torchvision matplotlib

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cấu hình
ROOT_PATH = "/kaggle/working/"
EPOCHS = 50
BATCH_SIZE = 128
NZ = 100
LR = 2e-4
OUTPUT_DIR = ROOT_PATH + "outputs_dcgan_cifar10"

# %%
class DCGAN_G(nn.Module):
    def __init__(self, nz=100, ngf=64, nc=3):
        super().__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        return self.main(z)


class DCGAN_D(nn.Module):
    def __init__(self, nc=3, ndf=64):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        out = self.main(x)
        return out.view(-1, 1)

# %%
def sample_noise(batch_size, nz, device):
    return torch.randn(batch_size, nz, 1, 1, device=device)


def train_dcgan_cifar10(epochs=50, batch_size=128, nz=100, lr=2e-4, outdir="outputs_dcgan_cifar10"):
    os.makedirs(outdir, exist_ok=True)

    transform = transforms.Compose([
        transforms.Resize(64),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5),
                             (0.5, 0.5, 0.5))
    ])

    dataset = datasets.CIFAR10(root="data", train=True, transform=transform, download=True)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)

    G = DCGAN_G(nz=nz, ngf=64, nc=3).to(device)
    D = DCGAN_D(nc=3, ndf=64).to(device)

    criterion = nn.BCELoss()
    optimizer_G = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
    optimizer_D = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))

    fixed_noise = sample_noise(64, nz, device)

    for epoch in range(epochs):
        for i, (real_imgs, _) in enumerate(loader):
            real_imgs = real_imgs.to(device)
            cur_bs = real_imgs.size(0)

            optimizer_D.zero_grad()
            labels_real = torch.ones(cur_bs, 1, device=device)
            labels_fake = torch.zeros(cur_bs, 1, device=device)

            out_real = D(real_imgs)
            loss_real = criterion(out_real, labels_real)

            z = sample_noise(cur_bs, nz, device)
            fake_imgs = G(z).detach()
            out_fake = D(fake_imgs)
            loss_fake = criterion(out_fake, labels_fake)

            loss_D = loss_real + loss_fake
            loss_D.backward()
            optimizer_D.step()

            optimizer_G.zero_grad()
            z = sample_noise(cur_bs, nz, device)
            fake_imgs = G(z)
            out_fake_for_G = D(fake_imgs)
            loss_G = criterion(out_fake_for_G, labels_real)
            loss_G.backward()
            optimizer_G.step()

            if i % 200 == 0:
                print(f"[DCGAN CIFAR10] Epoch [{epoch+1}/{epochs}] "
                      f"Step [{i}/{len(loader)}] "
                      f"Loss_D: {loss_D.item():.4f}, Loss_G: {loss_G.item():.4f}")

        with torch.no_grad():
            fake = G(fixed_noise).cpu()
            fake = (fake + 1) / 2
            grid = make_grid(fake, nrow=8)
            save_image(grid, os.path.join(outdir, f"dcgan_cifar10_epoch_{epoch+1:03d}.png"))

    print("Hoàn thành huấn luyện DCGAN, ảnh lưu trong:", outdir)

# %%
train_dcgan_cifar10(epochs=EPOCHS, batch_size=BATCH_SIZE, nz=NZ, lr=LR, outdir=OUTPUT_DIR)
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 47.3MB/s]
# [DCGAN CIFAR10] Epoch [1/50] Step [0/391] Loss_D: 1.3010, Loss_G: 2.3845
# [DCGAN CIFAR10] Epoch [1/50] Step [200/391] Loss_D: 0.4137, Loss_G: 2.9980
# [DCGAN CIFAR10] Epoch [2/50] Step [0/391] Loss_D: 0.6850, Loss_G: 2.8974
# [DCGAN CIFAR10] Epoch [2/50] Step [200/391] Loss_D: 0.2960, Loss_G: 3.2473
# [DCGAN CIFAR10] Epoch [3/50] Step [0/391] Loss_D: 0.5362, Loss_G: 3.2753
# [DCGAN CIFAR10] Epoch [3/50] Step [200/391] Loss_D: 0.2948, Loss_G: 2.8074
# [DCGAN CIFAR10] Epoch [4/50] Step [0/391] Loss_D: 0.3204, Loss_G: 2.6892
# [DCGAN CIFAR10] Epoch [4/50] Step [200/391] Loss_D: 0.6473, Loss_G: 2.7644
# [DCGAN CIFAR10] Epoch [5/50] Step [0/391] Loss_D: 1.1470, Loss_G: 5.9243
# [DCGAN CIFAR10] Epoch [5/50] Step [200/391] Loss_D: 0.2316, Loss_G: 3.8431
# [DCGAN CIFAR10] Epoch [6/50] Step [0/391] Loss_D: 0.6597, Loss_G: 4.6376
# [DCGAN CIFAR10] Epoch [6/50] Step [200/391] Loss_D: 0.0860, Loss_G: 4.3212
# [DCGAN CIFAR10] Epoch [7/50] Step [0/391] Loss_D: 0.0071, Loss_G: 8.9311
# [DCGAN CIFAR10] Epoch [7/50] Step [200/391] Loss_D: 0.2609, Loss_G: 4.6489
# [DCGAN CIFAR10] Epoch [8/50] Step [0/391] Loss_D: 0.0730, Loss_G: 4.6349
# [DCGAN CIFAR10] Epoch [8/50] Step [200/391] Loss_D: 0.0285, Loss_G: 5.6330
# [DCGAN CIFAR10] Epoch [9/50] Step [0/391] Loss_D: 0.0350, Loss_G: 3.9157
# [DCGAN CIFAR10] Epoch [9/50] Step [200/391] Loss_D: 0.6083, Loss_G: 5.0115
# [DCGAN CIFAR10] Epoch [10/50] Step [0/391] Loss_D: 0.0052, Loss_G: 7.9372
# [DCGAN CIFAR10] Epoch [10/50] Step [200/391] Loss_D: 1.1691, Loss_G: 5.7878
# [DCGAN CIFAR10] Epoch [11/50] Step [0/391] Loss_D: 0.0987, Loss_G: 5.2882
# [DCGAN CIFAR10] Epoch [11/50] Step [200/391] Loss_D: 0.0489, Loss_G: 8.0568
# [DCGAN CIFAR10] Epoch [12/50] Step [0/391] Loss_D: 0.0396, Loss_G: 4.1809
# [DCGAN CIFAR10] Epoch [12/50] Step [200/391] Loss_D: 0.0230, Loss_G: 6.4234
# [DCGAN CIFAR10] Epoch [13/50] Step [0/391] Loss_D: 0.0034, Loss_G: 10.3645
# [DCGAN CIFAR10] Epoch [13/50] Step [200/391] Loss_D: 0.1772, Loss_G: 7.8707
# [DCGAN CIFAR10] Epoch [14/50] Step [0/391] Loss_D: 0.0417, Loss_G: 3.9348
# [DCGAN CIFAR10] Epoch [14/50] Step [200/391] Loss_D: 0.3210, Loss_G: 3.3538
# [DCGAN CIFAR10] Epoch [15/50] Step [0/391] Loss_D: 0.3724, Loss_G: 2.6483
# [DCGAN CIFAR10] Epoch [15/50] Step [200/391] Loss_D: 0.0998, Loss_G: 4.8870
# [DCGAN CIFAR10] Epoch [16/50] Step [0/391] Loss_D: 0.0146, Loss_G: 6.3197
# [DCGAN CIFAR10] Epoch [16/50] Step [200/391] Loss_D: 0.0015, Loss_G: 10.3318
# [DCGAN CIFAR10] Epoch [17/50] Step [0/391] Loss_D: 0.4544, Loss_G: 6.8081
# [DCGAN CIFAR10] Epoch [17/50] Step [200/391] Loss_D: 0.0093, Loss_G: 6.0597
# [DCGAN CIFAR10] Epoch [18/50] Step [0/391] Loss_D: 0.1233, Loss_G: 4.5787
# [DCGAN CIFAR10] Epoch [18/50] Step [200/391] Loss_D: 0.0234, Loss_G: 4.8099
# [DCGAN CIFAR10] Epoch [19/50] Step [0/391] Loss_D: 0.1909, Loss_G: 3.0951
# [DCGAN CIFAR10] Epoch [19/50] Step [200/391] Loss_D: 0.4231, Loss_G: 5.8413
# [DCGAN CIFAR10] Epoch [20/50] Step [0/391] Loss_D: 0.0056, Loss_G: 7.5072
# [DCGAN CIFAR10] Epoch [20/50] Step [200/391] Loss_D: 0.0627, Loss_G: 7.6953
# [DCGAN CIFAR10] Epoch [21/50] Step [0/391] Loss_D: 1.0670, Loss_G: 5.6651
# [DCGAN CIFAR10] Epoch [21/50] Step [200/391] Loss_D: 0.0254, Loss_G: 5.6288
# [DCGAN CIFAR10] Epoch [22/50] Step [0/391] Loss_D: 0.1062, Loss_G: 4.3099
# [DCGAN CIFAR10] Epoch [22/50] Step [200/391] Loss_D: 0.0306, Loss_G: 5.4000
# [DCGAN CIFAR10] Epoch [23/50] Step [0/391] Loss_D: 0.4438, Loss_G: 3.0507
# [DCGAN CIFAR10] Epoch [23/50] Step [200/391] Loss_D: 0.0197, Loss_G: 5.2480
# [DCGAN CIFAR10] Epoch [24/50] Step [0/391] Loss_D: 0.4750, Loss_G: 6.1701
# [DCGAN CIFAR10] Epoch [24/50] Step [200/391] Loss_D: 0.0170, Loss_G: 4.7442
# [DCGAN CIFAR10] Epoch [25/50] Step [0/391] Loss_D: 0.1403, Loss_G: 7.5792
# [DCGAN CIFAR10] Epoch [25/50] Step [200/391] Loss_D: 0.3054, Loss_G: 5.8060
# [DCGAN CIFAR10] Epoch [26/50] Step [0/391] Loss_D: 0.3130, Loss_G: 10.4924
# [DCGAN CIFAR10] Epoch [26/50] Step [200/391] Loss_D: 0.2533, Loss_G: 6.3801
# [DCGAN CIFAR10] Epoch [27/50] Step [0/391] Loss_D: 0.0194, Loss_G: 5.1502
# [DCGAN CIFAR10] Epoch [27/50] Step [200/391] Loss_D: 0.0631, Loss_G: 5.0286
# [DCGAN CIFAR10] Epoch [28/50] Step [0/391] Loss_D: 0.6194, Loss_G: 2.6838
# [DCGAN CIFAR10] Epoch [28/50] Step [200/391] Loss_D: 0.0014, Loss_G: 10.7454
# [DCGAN CIFAR10] Epoch [29/50] Step [0/391] Loss_D: 0.4715, Loss_G: 3.3322
# [DCGAN CIFAR10] Epoch [29/50] Step [200/391] Loss_D: 0.0976, Loss_G: 4.4519
# [DCGAN CIFAR10] Epoch [30/50] Step [0/391] Loss_D: 0.0328, Loss_G: 6.1784
# [DCGAN CIFAR10] Epoch [30/50] Step [200/391] Loss_D: 0.0046, Loss_G: 7.3056
# [DCGAN CIFAR10] Epoch [31/50] Step [0/391] Loss_D: 0.2388, Loss_G: 2.8242
# [DCGAN CIFAR10] Epoch [31/50] Step [200/391] Loss_D: 0.4621, Loss_G: 3.2678
# [DCGAN CIFAR10] Epoch [32/50] Step [0/391] Loss_D: 0.1076, Loss_G: 5.2957
# [DCGAN CIFAR10] Epoch [32/50] Step [200/391] Loss_D: 1.6020, Loss_G: 7.3930
# [DCGAN CIFAR10] Epoch [33/50] Step [0/391] Loss_D: 0.0550, Loss_G: 5.2155
# [DCGAN CIFAR10] Epoch [33/50] Step [200/391] Loss_D: 0.0124, Loss_G: 6.9144
# [DCGAN CIFAR10] Epoch [34/50] Step [0/391] Loss_D: 0.0073, Loss_G: 6.1488
# [DCGAN CIFAR10] Epoch [34/50] Step [200/391] Loss_D: 0.0047, Loss_G: 6.7530
# [DCGAN CIFAR10] Epoch [35/50] Step [0/391] Loss_D: 0.0025, Loss_G: 8.2322
# [DCGAN CIFAR10] Epoch [35/50] Step [200/391] Loss_D: 0.0019, Loss_G: 15.9690
# [DCGAN CIFAR10] Epoch [36/50] Step [0/391] Loss_D: 0.0021, Loss_G: 6.4123
# [DCGAN CIFAR10] Epoch [36/50] Step [200/391] Loss_D: 0.0001, Loss_G: 16.2442
# [DCGAN CIFAR10] Epoch [37/50] Step [0/391] Loss_D: 0.0004, Loss_G: 11.2278
# [DCGAN CIFAR10] Epoch [37/50] Step [200/391] Loss_D: 0.0013, Loss_G: 13.6718
# [DCGAN CIFAR10] Epoch [38/50] Step [0/391] Loss_D: 0.0379, Loss_G: 5.5755
# [DCGAN CIFAR10] Epoch [38/50] Step [200/391] Loss_D: 0.0441, Loss_G: 6.6938
# [DCGAN CIFAR10] Epoch [39/50] Step [0/391] Loss_D: 0.1600, Loss_G: 12.5036
# [DCGAN CIFAR10] Epoch [39/50] Step [200/391] Loss_D: 0.0668, Loss_G: 4.3405
# [DCGAN CIFAR10] Epoch [40/50] Step [0/391] Loss_D: 0.0509, Loss_G: 4.6915
# [DCGAN CIFAR10] Epoch [40/50] Step [200/391] Loss_D: 0.2035, Loss_G: 6.2980
# [DCGAN CIFAR10] Epoch [41/50] Step [0/391] Loss_D: 0.3863, Loss_G: 4.1828
# [DCGAN CIFAR10] Epoch [41/50] Step [200/391] Loss_D: 0.1006, Loss_G: 6.6149
# [DCGAN CIFAR10] Epoch [42/50] Step [0/391] Loss_D: 0.0465, Loss_G: 12.0649
# [DCGAN CIFAR10] Epoch [42/50] Step [200/391] Loss_D: 0.0246, Loss_G: 6.5379
# [DCGAN CIFAR10] Epoch [43/50] Step [0/391] Loss_D: 0.0056, Loss_G: 8.7387
# [DCGAN CIFAR10] Epoch [43/50] Step [200/391] Loss_D: 0.0532, Loss_G: 4.1851
# [DCGAN CIFAR10] Epoch [44/50] Step [0/391] Loss_D: 0.9964, Loss_G: 5.7434
# [DCGAN CIFAR10] Epoch [44/50] Step [200/391] Loss_D: 0.0116, Loss_G: 4.7578
# [DCGAN CIFAR10] Epoch [45/50] Step [0/391] Loss_D: 0.1432, Loss_G: 3.8852
# [DCGAN CIFAR10] Epoch [45/50] Step [200/391] Loss_D: 0.2841, Loss_G: 3.5977
# [DCGAN CIFAR10] Epoch [46/50] Step [0/391] Loss_D: 0.0743, Loss_G: 4.8777
# [DCGAN CIFAR10] Epoch [46/50] Step [200/391] Loss_D: 0.1513, Loss_G: 5.8069
# [DCGAN CIFAR10] Epoch [47/50] Step [0/391] Loss_D: 0.0025, Loss_G: 7.7199
# [DCGAN CIFAR10] Epoch [47/50] Step [200/391] Loss_D: 0.2386, Loss_G: 3.5388
# [DCGAN CIFAR10] Epoch [48/50] Step [0/391] Loss_D: 0.0669, Loss_G: 4.9155
# [DCGAN CIFAR10] Epoch [48/50] Step [200/391] Loss_D: 0.0122, Loss_G: 5.3438
# [DCGAN CIFAR10] Epoch [49/50] Step [0/391] Loss_D: 0.0010, Loss_G: 9.8481
# [DCGAN CIFAR10] Epoch [49/50] Step [200/391] Loss_D: 0.0880, Loss_G: 4.7881
# [DCGAN CIFAR10] Epoch [50/50] Step [0/391] Loss_D: 0.0085, Loss_G: 6.9398
# [DCGAN CIFAR10] Epoch [50/50] Step [200/391] Loss_D: 0.4506, Loss_G: 2.7784
# Hoàn thành huấn luyện DCGAN, ảnh lưu trong: /kaggle/working/outputs_dcgan_cifar10
