# %% [markdown]
# # CycleGAN (toy) với dữ liệu unpaired
#
# Domain X: thư mục trainA, Domain Y: thư mục trainB.

# %%
# !pip install torch torchvision pillow

# %%
import os
import glob
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.utils import save_image
from PIL import Image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cấu hình
ROOT_PATH = "/kaggle/input/data-36"
DATA_A = ROOT_PATH + "/data/cyclegan_toy/trainA"
DATA_B = ROOT_PATH + "/data/cyclegan_toy/trainB"
OUTPUT_DIR =  "/kaggle/working/outputs_cyclegan_toy"
EPOCHS = 100
BATCH_SIZE = 2
LR = 2e-4
LAMBDA_CYCLE = 10.0
LAMBDA_ID = 5.0
IMG_SIZE = 128

# %%
class UnpairedDataset(Dataset):
    def __init__(self, dir_A, dir_B, transform=None):
        self.paths_A = sorted(glob.glob(os.path.join(dir_A, "*.png")))
        self.paths_B = sorted(glob.glob(os.path.join(dir_B, "*.png")))
        if len(self.paths_A) == 0 or len(self.paths_B) == 0:
            raise RuntimeError("No images in A or B")
        self.transform = transform

    def __len__(self):
        return max(len(self.paths_A), len(self.paths_B))

    def __getitem__(self, idx):
        path_A = self.paths_A[idx % len(self.paths_A)]
        path_B = self.paths_B[random.randint(0, len(self.paths_B) - 1)]
        img_A = Image.open(path_A).convert("RGB")
        img_B = Image.open(path_B).convert("RGB")
        if self.transform:
            img_A = self.transform(img_A)
            img_B = self.transform(img_B)
        return img_A, img_B

# %%
class ResnetBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(dim, dim, 3, 1, 1, bias=False),
            nn.InstanceNorm2d(dim),
            nn.ReLU(True),
            nn.Conv2d(dim, dim, 3, 1, 1, bias=False),
            nn.InstanceNorm2d(dim),
        )

    def forward(self, x):
        return x + self.block(x)


class ResnetGenerator(nn.Module):
    def __init__(self, in_ch=3, out_ch=3, n_blocks=6, ngf=64):
        super().__init__()
        model = [
            nn.Conv2d(in_ch, ngf, 7, 1, 3, bias=False),
            nn.InstanceNorm2d(ngf),
            nn.ReLU(True)
        ]
        cur_dim = ngf
        for _ in range(2):
            model += [
                nn.Conv2d(cur_dim, cur_dim * 2, 3, 2, 1, bias=False),
                nn.InstanceNorm2d(cur_dim * 2),
                nn.ReLU(True)
            ]
            cur_dim *= 2
        for _ in range(n_blocks):
            model += [ResnetBlock(cur_dim)]
        for _ in range(2):
            model += [
                nn.ConvTranspose2d(cur_dim, cur_dim // 2, 3, 2, 1, output_padding=1, bias=False),
                nn.InstanceNorm2d(cur_dim // 2),
                nn.ReLU(True)
            ]
            cur_dim //= 2
        model += [
            nn.Conv2d(cur_dim, out_ch, 7, 1, 3),
            nn.Tanh()
        ]
        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %%
class PatchDiscriminator(nn.Module):
    def __init__(self, in_ch=3, ndf=64):
        super().__init__()
        def block(in_c, out_c, norm=True):
            layers = [nn.Conv2d(in_c, out_c, 4, 2, 1, bias=False)]
            if norm:
                layers.append(nn.InstanceNorm2d(out_c))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(in_ch, ndf, norm=False),
            *block(ndf, ndf * 2),
            *block(ndf * 2, ndf * 4),
            nn.Conv2d(ndf * 4, 1, 4, 1, 1)
        )

    def forward(self, x):
        return self.model(x)

# %%
def train_cyclegan(dataA=DATA_A,
                   dataB=DATA_B,
                   outdir=OUTPUT_DIR,
                   epochs=EPOCHS,
                   batch_size=BATCH_SIZE,
                   lr=LR,
                   lambda_cycle=LAMBDA_CYCLE,
                   lambda_id=LAMBDA_ID,
                   img_size=IMG_SIZE):
    os.makedirs(outdir, exist_ok=True)

    transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5),
                             (0.5, 0.5, 0.5))
    ])

    dataset = UnpairedDataset(dataA, dataB, transform)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=0)

    G = ResnetGenerator(3, 3, n_blocks=3, ngf=64).to(device)
    F = ResnetGenerator(3, 3, n_blocks=3, ngf=64).to(device)
    D_X = PatchDiscriminator(3, ndf=64).to(device)
    D_Y = PatchDiscriminator(3, ndf=64).to(device)

    bce = nn.MSELoss()
    l1 = nn.L1Loss()

    opt_G = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_F = optim.Adam(F.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_DX = optim.Adam(D_X.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_DY = optim.Adam(D_Y.parameters(), lr=lr, betas=(0.5, 0.999))

    for epoch in range(epochs):
        for i, (real_X, real_Y) in enumerate(loader):
            real_X = real_X.to(device)
            real_Y = real_Y.to(device)
            cur_bs = real_X.size(0)

            valid_X = torch.ones(cur_bs, 1, 1, 1, device=device)
            fake_X_lbl = torch.zeros(cur_bs, 1, 1, 1, device=device)
            valid_Y = torch.ones(cur_bs, 1, 1, 1, device=device)
            fake_Y_lbl = torch.zeros(cur_bs, 1, 1, 1, device=device)

            opt_G.zero_grad()
            opt_F.zero_grad()

            fake_Y = G(real_X)
            fake_X = F(real_Y)

            pred_fake_Y = D_Y(fake_Y)
            pred_fake_X = D_X(fake_X)
            loss_G_gan = bce(pred_fake_Y, valid_Y)
            loss_F_gan = bce(pred_fake_X, valid_X)

            rec_X = F(fake_Y)
            rec_Y = G(fake_X)
            loss_cycle_X = l1(rec_X, real_X)
            loss_cycle_Y = l1(rec_Y, real_Y)
            loss_cycle_total = (loss_cycle_X + loss_cycle_Y) * lambda_cycle

            id_X = F(real_X)
            id_Y = G(real_Y)
            loss_id_X = l1(id_X, real_X) * lambda_id
            loss_id_Y = l1(id_Y, real_Y) * lambda_id

            loss_G_total = loss_G_gan + loss_F_gan + loss_cycle_total + loss_id_X + loss_id_Y
            loss_G_total.backward()
            opt_G.step()
            opt_F.step()

            opt_DX.zero_grad()
            pred_real_X = D_X(real_X)
            pred_fake_X = D_X(fake_X.detach())
            loss_DX_real = bce(pred_real_X, valid_X)
            loss_DX_fake = bce(pred_fake_X, fake_X_lbl)
            loss_DX = (loss_DX_real + loss_DX_fake) * 0.5
            loss_DX.backward()
            opt_DX.step()

            opt_DY.zero_grad()
            pred_real_Y = D_Y(real_Y)
            pred_fake_Y = D_Y(fake_Y.detach())
            loss_DY_real = bce(pred_real_Y, valid_Y)
            loss_DY_fake = bce(pred_fake_Y, fake_Y_lbl)
            loss_DY = (loss_DY_real + loss_DY_fake) * 0.5
            loss_DY.backward()
            opt_DY.step()

            if i % 50 == 0:
                print(f"[CycleGAN] Epoch [{epoch+1}/{epochs}] "
                      f"Step [{i}/{len(loader)}] "
                      f"Loss_G: {loss_G_total.item():.4f} "
                      f"Loss_DX: {loss_DX.item():.4f} "
                      f"Loss_DY: {loss_DY.item():.4f}")

        with torch.no_grad():
            real_X_sample, real_Y_sample = next(iter(loader))
            real_X_sample = real_X_sample.to(device)
            real_Y_sample = real_Y_sample.to(device)
            fake_Y_sample = G(real_X_sample)
            rec_X_sample = F(fake_Y_sample)

            def denorm(x):
                return (x + 1) / 2

            grid = torch.cat([denorm(real_X_sample),
                              denorm(fake_Y_sample),
                              denorm(rec_X_sample)], dim=0)
            save_image(grid, os.path.join(outdir, f"X2Y_epoch_{epoch+1:03d}.png"),
                       nrow=real_X_sample.size(0))

            fake_X_sample = F(real_Y_sample)
            rec_Y_sample = G(fake_X_sample)
            grid2 = torch.cat([denorm(real_Y_sample),
                               denorm(fake_X_sample),
                               denorm(rec_Y_sample)], dim=0)
            save_image(grid2, os.path.join(outdir, f"Y2X_epoch_{epoch+1:03d}.png"),
                       nrow=real_Y_sample.size(0))

    print("Huấn luyện CycleGAN xong, ảnh kết quả trong:", outdir)

# %%
train_cyclegan()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py:610: UserWarning: Using a target size (torch.Size([2, 1, 1, 1])) that is different to the input size (torch.Size([2, 1, 15, 15])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [CycleGAN] Epoch [1/100] Step [0/250] Loss_G: 29.5296 Loss_DX: 0.8536 Loss_DY: 0.4803
# [CycleGAN] Epoch [1/100] Step [50/250] Loss_G: 2.3372 Loss_DX: 0.2236 Loss_DY: 0.2253
# [CycleGAN] Epoch [1/100] Step [100/250] Loss_G: 1.6240 Loss_DX: 0.2741 Loss_DY: 0.2885
# [CycleGAN] Epoch [1/100] Step [150/250] Loss_G: 1.4008 Loss_DX: 0.2425 Loss_DY: 0.2980
# [CycleGAN] Epoch [1/100] Step [200/250] Loss_G: 1.2899 Loss_DX: 0.2526 Loss_DY: 0.2462
# [CycleGAN] Epoch [2/100] Step [0/250] Loss_G: 1.3399 Loss_DX: 0.2364 Loss_DY: 0.2402
# [CycleGAN] Epoch [2/100] Step [50/250] Loss_G: 1.2483 Loss_DX: 0.2564 Loss_DY: 0.2558
# [CycleGAN] Epoch [2/100] Step [100/250] Loss_G: 1.6086 Loss_DX: 0.1870 Loss_DY: 0.1743
# [CycleGAN] Epoch [2/100] Step [150/250] Loss_G: 1.2373 Loss_DX: 0.2713 Loss_DY: 0.2509
# [CycleGAN] Epoch [2/100] Step [200/250] Loss_G: 1.3401 Loss_DX: 0.2284 Loss_DY: 0.2175
# [CycleGAN] Epoch [3/100] Step [0/250] Loss_G: 1.3601 Loss_DX: 0.2139 Loss_DY: 0.2166
# [CycleGAN] Epoch [3/100] Step [50/250] Loss_G: 1.2070 Loss_DX: 0.2699 Loss_DY: 0.2817
# [CycleGAN] Epoch [3/100] Step [100/250] Loss_G: 1.3847 Loss_DX: 0.1706 Loss_DY: 0.1829
# [CycleGAN] Epoch [3/100] Step [150/250] Loss_G: 1.2665 Loss_DX: 0.2210 Loss_DY: 0.2188
# [CycleGAN] Epoch [3/100] Step [200/250] Loss_G: 1.1472 Loss_DX: 0.2328 Loss_DY: 0.2429
# [CycleGAN] Epoch [4/100] Step [0/250] Loss_G: 1.3524 Loss_DX: 0.1905 Loss_DY: 0.1860
# [CycleGAN] Epoch [4/100] Step [50/250] Loss_G: 1.6144 Loss_DX: 0.3121 Loss_DY: 0.2359
# [CycleGAN] Epoch [4/100] Step [100/250] Loss_G: 1.7476 Loss_DX: 0.1504 Loss_DY: 0.1678
# [CycleGAN] Epoch [4/100] Step [150/250] Loss_G: 1.3828 Loss_DX: 0.1568 Loss_DY: 0.1828
# [CycleGAN] Epoch [4/100] Step [200/250] Loss_G: 1.2473 Loss_DX: 0.1909 Loss_DY: 0.2282
# [CycleGAN] Epoch [5/100] Step [0/250] Loss_G: 1.2487 Loss_DX: 0.2188 Loss_DY: 0.2122
# [CycleGAN] Epoch [5/100] Step [50/250] Loss_G: 1.4124 Loss_DX: 0.2042 Loss_DY: 0.2607
# [CycleGAN] Epoch [5/100] Step [100/250] Loss_G: 1.2975 Loss_DX: 0.2314 Loss_DY: 0.2251
# [CycleGAN] Epoch [5/100] Step [150/250] Loss_G: 1.4993 Loss_DX: 0.1882 Loss_DY: 0.2032
# [CycleGAN] Epoch [5/100] Step [200/250] Loss_G: 1.4470 Loss_DX: 0.1733 Loss_DY: 0.1960
# [CycleGAN] Epoch [6/100] Step [0/250] Loss_G: 1.1834 Loss_DX: 0.2733 Loss_DY: 0.2876
# [CycleGAN] Epoch [6/100] Step [50/250] Loss_G: 1.0095 Loss_DX: 0.1708 Loss_DY: 0.2066
# [CycleGAN] Epoch [6/100] Step [100/250] Loss_G: 1.1041 Loss_DX: 0.2755 Loss_DY: 0.2555
# [CycleGAN] Epoch [6/100] Step [150/250] Loss_G: 1.2553 Loss_DX: 0.2182 Loss_DY: 0.1972
# [CycleGAN] Epoch [6/100] Step [200/250] Loss_G: 1.2256 Loss_DX: 0.1039 Loss_DY: 0.1445
# [CycleGAN] Epoch [7/100] Step [0/250] Loss_G: 1.0741 Loss_DX: 0.1531 Loss_DY: 0.2054
# [CycleGAN] Epoch [7/100] Step [50/250] Loss_G: 1.8470 Loss_DX: 0.2846 Loss_DY: 0.2619
# [CycleGAN] Epoch [7/100] Step [100/250] Loss_G: 1.0957 Loss_DX: 0.2185 Loss_DY: 0.2238
# [CycleGAN] Epoch [7/100] Step [150/250] Loss_G: 1.2558 Loss_DX: 0.2100 Loss_DY: 0.2117
# [CycleGAN] Epoch [7/100] Step [200/250] Loss_G: 1.1650 Loss_DX: 0.2495 Loss_DY: 0.2549
# [CycleGAN] Epoch [8/100] Step [0/250] Loss_G: 1.0227 Loss_DX: 0.1746 Loss_DY: 0.2159
# [CycleGAN] Epoch [8/100] Step [50/250] Loss_G: 1.4522 Loss_DX: 0.2403 Loss_DY: 0.2238
# [CycleGAN] Epoch [8/100] Step [100/250] Loss_G: 1.0338 Loss_DX: 0.1578 Loss_DY: 0.2159
# [CycleGAN] Epoch [8/100] Step [150/250] Loss_G: 1.0550 Loss_DX: 0.2014 Loss_DY: 0.2328
# [CycleGAN] Epoch [8/100] Step [200/250] Loss_G: 1.4067 Loss_DX: 0.1927 Loss_DY: 0.1831
# [CycleGAN] Epoch [9/100] Step [0/250] Loss_G: 1.0642 Loss_DX: 0.1054 Loss_DY: 0.2230
# [CycleGAN] Epoch [9/100] Step [50/250] Loss_G: 0.9825 Loss_DX: 0.3097 Loss_DY: 0.2962
# [CycleGAN] Epoch [9/100] Step [100/250] Loss_G: 1.0026 Loss_DX: 0.2480 Loss_DY: 0.2625
# [CycleGAN] Epoch [9/100] Step [150/250] Loss_G: 1.3219 Loss_DX: 0.1406 Loss_DY: 0.1962
# [CycleGAN] Epoch [9/100] Step [200/250] Loss_G: 1.1697 Loss_DX: 0.1924 Loss_DY: 0.1371
# [CycleGAN] Epoch [10/100] Step [0/250] Loss_G: 1.5545 Loss_DX: 0.1477 Loss_DY: 0.1477
# [CycleGAN] Epoch [10/100] Step [50/250] Loss_G: 1.1843 Loss_DX: 0.2393 Loss_DY: 0.2345
# [CycleGAN] Epoch [10/100] Step [100/250] Loss_G: 0.9687 Loss_DX: 0.1513 Loss_DY: 0.2203
# [CycleGAN] Epoch [10/100] Step [150/250] Loss_G: 1.2431 Loss_DX: 0.2403 Loss_DY: 0.1880
# [CycleGAN] Epoch [10/100] Step [200/250] Loss_G: 1.2084 Loss_DX: 0.1720 Loss_DY: 0.2113
# [CycleGAN] Epoch [11/100] Step [0/250] Loss_G: 1.0243 Loss_DX: 0.1874 Loss_DY: 0.2030
# [CycleGAN] Epoch [11/100] Step [50/250] Loss_G: 0.9284 Loss_DX: 0.2415 Loss_DY: 0.2473
# [CycleGAN] Epoch [11/100] Step [100/250] Loss_G: 1.5381 Loss_DX: 0.1695 Loss_DY: 0.1876
# [CycleGAN] Epoch [11/100] Step [150/250] Loss_G: 1.4240 Loss_DX: 0.0991 Loss_DY: 0.1396
# [CycleGAN] Epoch [11/100] Step [200/250] Loss_G: 1.3137 Loss_DX: 0.1492 Loss_DY: 0.1635
# [CycleGAN] Epoch [12/100] Step [0/250] Loss_G: 1.1908 Loss_DX: 0.0792 Loss_DY: 0.1821
# [CycleGAN] Epoch [12/100] Step [50/250] Loss_G: 0.9823 Loss_DX: 0.3294 Loss_DY: 0.2351
# [CycleGAN] Epoch [12/100] Step [100/250] Loss_G: 1.3104 Loss_DX: 0.1601 Loss_DY: 0.2126
# [CycleGAN] Epoch [12/100] Step [150/250] Loss_G: 1.4987 Loss_DX: 0.2545 Loss_DY: 0.2172
# [CycleGAN] Epoch [12/100] Step [200/250] Loss_G: 0.8511 Loss_DX: 0.2852 Loss_DY: 0.3039
# [CycleGAN] Epoch [13/100] Step [0/250] Loss_G: 1.4410 Loss_DX: 0.1215 Loss_DY: 0.1855
# [CycleGAN] Epoch [13/100] Step [50/250] Loss_G: 1.3723 Loss_DX: 0.1857 Loss_DY: 0.1210
# [CycleGAN] Epoch [13/100] Step [100/250] Loss_G: 1.0142 Loss_DX: 0.2656 Loss_DY: 0.2238
# [CycleGAN] Epoch [13/100] Step [150/250] Loss_G: 1.5365 Loss_DX: 0.1828 Loss_DY: 0.1147
# [CycleGAN] Epoch [13/100] Step [200/250] Loss_G: 1.1169 Loss_DX: 0.2182 Loss_DY: 0.2316
# [CycleGAN] Epoch [14/100] Step [0/250] Loss_G: 1.1540 Loss_DX: 0.2085 Loss_DY: 0.2280
# [CycleGAN] Epoch [14/100] Step [50/250] Loss_G: 1.7885 Loss_DX: 0.1045 Loss_DY: 0.2060
# [CycleGAN] Epoch [14/100] Step [100/250] Loss_G: 1.1784 Loss_DX: 0.2010 Loss_DY: 0.2210
# [CycleGAN] Epoch [14/100] Step [150/250] Loss_G: 1.4010 Loss_DX: 0.0801 Loss_DY: 0.1845
# [CycleGAN] Epoch [14/100] Step [200/250] Loss_G: 1.1050 Loss_DX: 0.1990 Loss_DY: 0.2276
# [CycleGAN] Epoch [15/100] Step [0/250] Loss_G: 1.1956 Loss_DX: 0.2013 Loss_DY: 0.1565
# [CycleGAN] Epoch [15/100] Step [50/250] Loss_G: 1.2984 Loss_DX: 0.1955 Loss_DY: 0.2257
# [CycleGAN] Epoch [15/100] Step [100/250] Loss_G: 1.2079 Loss_DX: 0.2572 Loss_DY: 0.2530
# [CycleGAN] Epoch [15/100] Step [150/250] Loss_G: 1.3393 Loss_DX: 0.1675 Loss_DY: 0.2457
# [CycleGAN] Epoch [15/100] Step [200/250] Loss_G: 1.4454 Loss_DX: 0.1182 Loss_DY: 0.1872
# [CycleGAN] Epoch [16/100] Step [0/250] Loss_G: 1.2325 Loss_DX: 0.0698 Loss_DY: 0.1590
# [CycleGAN] Epoch [16/100] Step [50/250] Loss_G: 1.1053 Loss_DX: 0.2985 Loss_DY: 0.2744
# [CycleGAN] Epoch [16/100] Step [100/250] Loss_G: 1.1032 Loss_DX: 0.1344 Loss_DY: 0.1757
# [CycleGAN] Epoch [16/100] Step [150/250] Loss_G: 1.4584 Loss_DX: 0.1660 Loss_DY: 0.1631
# [CycleGAN] Epoch [16/100] Step [200/250] Loss_G: 1.1011 Loss_DX: 0.2608 Loss_DY: 0.1695
# [CycleGAN] Epoch [17/100] Step [0/250] Loss_G: 1.2409 Loss_DX: 0.1267 Loss_DY: 0.1569
# [CycleGAN] Epoch [17/100] Step [50/250] Loss_G: 1.1378 Loss_DX: 0.2684 Loss_DY: 0.2037
# [CycleGAN] Epoch [17/100] Step [100/250] Loss_G: 1.2973 Loss_DX: 0.1584 Loss_DY: 0.1503
# [CycleGAN] Epoch [17/100] Step [150/250] Loss_G: 1.5036 Loss_DX: 0.2358 Loss_DY: 0.2175
# [CycleGAN] Epoch [17/100] Step [200/250] Loss_G: 1.1296 Loss_DX: 0.2602 Loss_DY: 0.1449
# [CycleGAN] Epoch [18/100] Step [0/250] Loss_G: 0.9139 Loss_DX: 0.2087 Loss_DY: 0.3170
# [CycleGAN] Epoch [18/100] Step [50/250] Loss_G: 1.5643 Loss_DX: 0.2105 Loss_DY: 0.1269
# [CycleGAN] Epoch [33/100] Step [0/250] Loss_G: 1.7866 Loss_DX: 0.1305 Loss_DY: 0.1010
# [CycleGAN] Epoch [33/100] Step [50/250] Loss_G: 1.5953 Loss_DX: 0.2352 Loss_DY: 0.2544
# [CycleGAN] Epoch [33/100] Step [100/250] Loss_G: 1.3981 Loss_DX: 0.2034 Loss_DY: 0.2053
# [CycleGAN] Epoch [33/100] Step [150/250] Loss_G: 1.4857 Loss_DX: 0.0663 Loss_DY: 0.1528
# [CycleGAN] Epoch [33/100] Step [200/250] Loss_G: 1.2342 Loss_DX: 0.1431 Loss_DY: 0.1028
# [CycleGAN] Epoch [34/100] Step [0/250] Loss_G: 0.9717 Loss_DX: 0.1752 Loss_DY: 0.2569
# [CycleGAN] Epoch [34/100] Step [50/250] Loss_G: 1.7826 Loss_DX: 0.2429 Loss_DY: 0.2039
# [CycleGAN] Epoch [34/100] Step [100/250] Loss_G: 1.0833 Loss_DX: 0.1581 Loss_DY: 0.1516
# [CycleGAN] Epoch [34/100] Step [150/250] Loss_G: 1.3600 Loss_DX: 0.2649 Loss_DY: 0.1607
# [CycleGAN] Epoch [34/100] Step [200/250] Loss_G: 1.2918 Loss_DX: 0.2409 Loss_DY: 0.2397
# [CycleGAN] Epoch [35/100] Step [0/250] Loss_G: 1.5473 Loss_DX: 0.1341 Loss_DY: 0.2241
# [CycleGAN] Epoch [35/100] Step [50/250] Loss_G: 1.1877 Loss_DX: 0.2003 Loss_DY: 0.2216
# [CycleGAN] Epoch [35/100] Step [100/250] Loss_G: 1.1923 Loss_DX: 0.2527 Loss_DY: 0.2471
# [CycleGAN] Epoch [35/100] Step [150/250] Loss_G: 1.5665 Loss_DX: 0.1497 Loss_DY: 0.1105
# [CycleGAN] Epoch [35/100] Step [200/250] Loss_G: 1.2043 Loss_DX: 0.1972 Loss_DY: 0.2719
# [CycleGAN] Epoch [36/100] Step [0/250] Loss_G: 1.0354 Loss_DX: 0.1554 Loss_DY: 0.1711
# [CycleGAN] Epoch [36/100] Step [50/250] Loss_G: 1.4403 Loss_DX: 0.2447 Loss_DY: 0.1474
# [CycleGAN] Epoch [36/100] Step [100/250] Loss_G: 1.4611 Loss_DX: 0.1078 Loss_DY: 0.0913
# [CycleGAN] Epoch [36/100] Step [150/250] Loss_G: 1.5604 Loss_DX: 0.1746 Loss_DY: 0.1955
# [CycleGAN] Epoch [36/100] Step [200/250] Loss_G: 1.4268 Loss_DX: 0.1942 Loss_DY: 0.1566
# [CycleGAN] Epoch [37/100] Step [0/250] Loss_G: 1.5327 Loss_DX: 0.1209 Loss_DY: 0.1977
# [CycleGAN] Epoch [37/100] Step [50/250] Loss_G: 1.2450 Loss_DX: 0.1263 Loss_DY: 0.1848
# [CycleGAN] Epoch [37/100] Step [100/250] Loss_G: 1.3518 Loss_DX: 0.0747 Loss_DY: 0.1421
# [CycleGAN] Epoch [37/100] Step [150/250] Loss_G: 1.5327 Loss_DX: 0.1671 Loss_DY: 0.0991
# [CycleGAN] Epoch [42/100] Step [150/250] Loss_G: 1.2361 Loss_DX: 0.1311 Loss_DY: 0.1285
# [CycleGAN] Epoch [42/100] Step [200/250] Loss_G: 1.5949 Loss_DX: 0.2210 Loss_DY: 0.1608
# [CycleGAN] Epoch [43/100] Step [0/250] Loss_G: 1.4781 Loss_DX: 0.1241 Loss_DY: 0.1502
# [CycleGAN] Epoch [43/100] Step [50/250] Loss_G: 1.3262 Loss_DX: 0.1291 Loss_DY: 0.1867
# [CycleGAN] Epoch [43/100] Step [100/250] Loss_G: 1.4479 Loss_DX: 0.2429 Loss_DY: 0.1520
# [CycleGAN] Epoch [43/100] Step [150/250] Loss_G: 1.3894 Loss_DX: 0.1536 Loss_DY: 0.1413
# [CycleGAN] Epoch [43/100] Step [200/250] Loss_G: 1.7688 Loss_DX: 0.1796 Loss_DY: 0.1210
# [CycleGAN] Epoch [44/100] Step [0/250] Loss_G: 1.2624 Loss_DX: 0.1664 Loss_DY: 0.1361
# [CycleGAN] Epoch [44/100] Step [50/250] Loss_G: 1.5836 Loss_DX: 0.1283 Loss_DY: 0.1161
# [CycleGAN] Epoch [44/100] Step [100/250] Loss_G: 1.2122 Loss_DX: 0.1994 Loss_DY: 0.1886
# [CycleGAN] Epoch [44/100] Step [150/250] Loss_G: 1.1075 Loss_DX: 0.1189 Loss_DY: 0.2124
# [CycleGAN] Epoch [44/100] Step [200/250] Loss_G: 1.1578 Loss_DX: 0.1834 Loss_DY: 0.2014
# [CycleGAN] Epoch [45/100] Step [0/250] Loss_G: 1.3492 Loss_DX: 0.2309 Loss_DY: 0.1967
# [CycleGAN] Epoch [45/100] Step [50/250] Loss_G: 1.2779 Loss_DX: 0.2039 Loss_DY: 0.2283
# [CycleGAN] Epoch [45/100] Step [100/250] Loss_G: 1.2003 Loss_DX: 0.3494 Loss_DY: 0.1487
# [CycleGAN] Epoch [45/100] Step [150/250] Loss_G: 1.4587 Loss_DX: 0.1418 Loss_DY: 0.1756
# [CycleGAN] Epoch [45/100] Step [200/250] Loss_G: 1.5157 Loss_DX: 0.1006 Loss_DY: 0.1320
# [CycleGAN] Epoch [46/100] Step [0/250] Loss_G: 1.5482 Loss_DX: 0.2222 Loss_DY: 0.1177
# [CycleGAN] Epoch [46/100] Step [50/250] Loss_G: 1.6072 Loss_DX: 0.2452 Loss_DY: 0.2061
# [CycleGAN] Epoch [46/100] Step [100/250] Loss_G: 1.6192 Loss_DX: 0.2061 Loss_DY: 0.1849
# [CycleGAN] Epoch [46/100] Step [150/250] Loss_G: 1.7033 Loss_DX: 0.1568 Loss_DY: 0.2437
# [CycleGAN] Epoch [46/100] Step [200/250] Loss_G: 1.2744 Loss_DX: 0.1678 Loss_DY: 0.1706
# [CycleGAN] Epoch [47/100] Step [0/250] Loss_G: 1.8707 Loss_DX: 0.3745 Loss_DY: 0.1521
# [CycleGAN] Epoch [47/100] Step [50/250] Loss_G: 1.5837 Loss_DX: 0.1197 Loss_DY: 0.1189
# [CycleGAN] Epoch [47/100] Step [100/250] Loss_G: 1.2667 Loss_DX: 0.1616 Loss_DY: 0.2615
# [CycleGAN] Epoch [47/100] Step [150/250] Loss_G: 1.4160 Loss_DX: 0.1071 Loss_DY: 0.2058
# [CycleGAN] Epoch [47/100] Step [200/250] Loss_G: 1.5715 Loss_DX: 0.2253 Loss_DY: 0.0955
# [CycleGAN] Epoch [48/100] Step [0/250] Loss_G: 1.2502 Loss_DX: 0.2015 Loss_DY: 0.1368
# [CycleGAN] Epoch [48/100] Step [50/250] Loss_G: 1.4189 Loss_DX: 0.1132 Loss_DY: 0.1492
# [CycleGAN] Epoch [48/100] Step [100/250] Loss_G: 1.2117 Loss_DX: 0.1664 Loss_DY: 0.1602
# [CycleGAN] Epoch [48/100] Step [150/250] Loss_G: 1.2830 Loss_DX: 0.2114 Loss_DY: 0.1565
# [CycleGAN] Epoch [48/100] Step [200/250] Loss_G: 1.2640 Loss_DX: 0.1525 Loss_DY: 0.1011
# [CycleGAN] Epoch [49/100] Step [0/250] Loss_G: 1.0992 Loss_DX: 0.3139 Loss_DY: 0.1640
# [CycleGAN] Epoch [49/100] Step [50/250] Loss_G: 1.1831 Loss_DX: 0.1332 Loss_DY: 0.2220
# [CycleGAN] Epoch [49/100] Step [100/250] Loss_G: 1.3580 Loss_DX: 0.1806 Loss_DY: 0.1770
# [CycleGAN] Epoch [49/100] Step [150/250] Loss_G: 1.3721 Loss_DX: 0.1798 Loss_DY: 0.1378
# [CycleGAN] Epoch [49/100] Step [200/250] Loss_G: 1.0789 Loss_DX: 0.1908 Loss_DY: 0.1477
# [CycleGAN] Epoch [50/100] Step [0/250] Loss_G: 1.7485 Loss_DX: 0.0825 Loss_DY: 0.1000
# [CycleGAN] Epoch [50/100] Step [50/250] Loss_G: 1.3782 Loss_DX: 0.1617 Loss_DY: 0.1376
# [CycleGAN] Epoch [50/100] Step [100/250] Loss_G: 1.1749 Loss_DX: 0.1697 Loss_DY: 0.1785
# [CycleGAN] Epoch [50/100] Step [150/250] Loss_G: 1.4314 Loss_DX: 0.1493 Loss_DY: 0.2202
# [CycleGAN] Epoch [50/100] Step [200/250] Loss_G: 1.4679 Loss_DX: 0.3075 Loss_DY: 0.1492
# [CycleGAN] Epoch [51/100] Step [0/250] Loss_G: 1.3401 Loss_DX: 0.2359 Loss_DY: 0.2476
# [CycleGAN] Epoch [51/100] Step [50/250] Loss_G: 1.8396 Loss_DX: 0.1564 Loss_DY: 0.1658
# [CycleGAN] Epoch [51/100] Step [100/250] Loss_G: 1.2661 Loss_DX: 0.1017 Loss_DY: 0.1342
# [CycleGAN] Epoch [51/100] Step [150/250] Loss_G: 1.3856 Loss_DX: 0.2601 Loss_DY: 0.2177
# [CycleGAN] Epoch [51/100] Step [200/250] Loss_G: 1.2328 Loss_DX: 0.1524 Loss_DY: 0.1731
# [CycleGAN] Epoch [52/100] Step [0/250] Loss_G: 1.0585 Loss_DX: 0.1784 Loss_DY: 0.1477
# [CycleGAN] Epoch [52/100] Step [50/250] Loss_G: 1.0460 Loss_DX: 0.1358 Loss_DY: 0.1748
# [CycleGAN] Epoch [52/100] Step [100/250] Loss_G: 1.1258 Loss_DX: 0.1333 Loss_DY: 0.1251
# [CycleGAN] Epoch [52/100] Step [150/250] Loss_G: 1.1699 Loss_DX: 0.1286 Loss_DY: 0.0963
# [CycleGAN] Epoch [52/100] Step [200/250] Loss_G: 1.1314 Loss_DX: 0.1278 Loss_DY: 0.1560
# [CycleGAN] Epoch [53/100] Step [0/250] Loss_G: 1.3774 Loss_DX: 0.2243 Loss_DY: 0.1048
# [CycleGAN] Epoch [53/100] Step [50/250] Loss_G: 1.5857 Loss_DX: 0.2329 Loss_DY: 0.0918
# [CycleGAN] Epoch [53/100] Step [100/250] Loss_G: 1.5718 Loss_DX: 0.3350 Loss_DY: 0.1916
# [CycleGAN] Epoch [53/100] Step [150/250] Loss_G: 1.7901 Loss_DX: 0.2764 Loss_DY: 0.1911
# [CycleGAN] Epoch [53/100] Step [200/250] Loss_G: 1.5445 Loss_DX: 0.1326 Loss_DY: 0.1429
# [CycleGAN] Epoch [54/100] Step [0/250] Loss_G: 1.2499 Loss_DX: 0.1829 Loss_DY: 0.1788
# [CycleGAN] Epoch [54/100] Step [50/250] Loss_G: 1.7215 Loss_DX: 0.0753 Loss_DY: 0.1049
# [CycleGAN] Epoch [54/100] Step [100/250] Loss_G: 1.3086 Loss_DX: 0.1225 Loss_DY: 0.1760
# [CycleGAN] Epoch [54/100] Step [150/250] Loss_G: 1.4115 Loss_DX: 0.1667 Loss_DY: 0.1852
# [CycleGAN] Epoch [54/100] Step [200/250] Loss_G: 1.2395 Loss_DX: 0.1293 Loss_DY: 0.2223
# [CycleGAN] Epoch [55/100] Step [0/250] Loss_G: 1.7275 Loss_DX: 0.2065 Loss_DY: 0.1569
# [CycleGAN] Epoch [55/100] Step [50/250] Loss_G: 1.2138 Loss_DX: 0.1250 Loss_DY: 0.1483
# [CycleGAN] Epoch [55/100] Step [100/250] Loss_G: 1.0041 Loss_DX: 0.2148 Loss_DY: 0.2462
# [CycleGAN] Epoch [55/100] Step [150/250] Loss_G: 1.1126 Loss_DX: 0.2148 Loss_DY: 0.2344
# [CycleGAN] Epoch [55/100] Step [200/250] Loss_G: 1.4650 Loss_DX: 0.1626 Loss_DY: 0.1262
# [CycleGAN] Epoch [56/100] Step [0/250] Loss_G: 1.1182 Loss_DX: 0.2570 Loss_DY: 0.1553
# [CycleGAN] Epoch [56/100] Step [50/250] Loss_G: 1.1687 Loss_DX: 0.1822 Loss_DY: 0.1881
# [CycleGAN] Epoch [56/100] Step [100/250] Loss_G: 1.2501 Loss_DX: 0.1217 Loss_DY: 0.1136
# [CycleGAN] Epoch [56/100] Step [150/250] Loss_G: 0.8854 Loss_DX: 0.1704 Loss_DY: 0.1903
# [CycleGAN] Epoch [56/100] Step [200/250] Loss_G: 0.9980 Loss_DX: 0.2079 Loss_DY: 0.1345
# [CycleGAN] Epoch [57/100] Step [0/250] Loss_G: 1.2207 Loss_DX: 0.1352 Loss_DY: 0.1213
# [CycleGAN] Epoch [57/100] Step [50/250] Loss_G: 1.1616 Loss_DX: 0.1889 Loss_DY: 0.2064
# [CycleGAN] Epoch [57/100] Step [100/250] Loss_G: 1.3515 Loss_DX: 0.2102 Loss_DY: 0.2380
# [CycleGAN] Epoch [57/100] Step [150/250] Loss_G: 1.2424 Loss_DX: 0.1300 Loss_DY: 0.1321
# [CycleGAN] Epoch [57/100] Step [200/250] Loss_G: 1.3526 Loss_DX: 0.1553 Loss_DY: 0.1880
# [CycleGAN] Epoch [58/100] Step [0/250] Loss_G: 1.2296 Loss_DX: 0.1402 Loss_DY: 0.1973
# [CycleGAN] Epoch [58/100] Step [50/250] Loss_G: 1.4993 Loss_DX: 0.1347 Loss_DY: 0.1319
# [CycleGAN] Epoch [58/100] Step [100/250] Loss_G: 1.0095 Loss_DX: 0.2734 Loss_DY: 0.2028
# [CycleGAN] Epoch [58/100] Step [150/250] Loss_G: 1.4194 Loss_DX: 0.1031 Loss_DY: 0.1746
# [CycleGAN] Epoch [58/100] Step [200/250] Loss_G: 1.1685 Loss_DX: 0.0954 Loss_DY: 0.2028
# [CycleGAN] Epoch [59/100] Step [0/250] Loss_G: 1.1775 Loss_DX: 0.1793 Loss_DY: 0.1777
# [CycleGAN] Epoch [59/100] Step [50/250] Loss_G: 0.9446 Loss_DX: 0.1498 Loss_DY: 0.1654
# [CycleGAN] Epoch [59/100] Step [100/250] Loss_G: 1.2594 Loss_DX: 0.1615 Loss_DY: 0.1298
# [CycleGAN] Epoch [59/100] Step [150/250] Loss_G: 0.8891 Loss_DX: 0.3978 Loss_DY: 0.1814
# [CycleGAN] Epoch [59/100] Step [200/250] Loss_G: 1.1999 Loss_DX: 0.1281 Loss_DY: 0.1958
# [CycleGAN] Epoch [60/100] Step [0/250] Loss_G: 1.1700 Loss_DX: 0.1694 Loss_DY: 0.1334
# [CycleGAN] Epoch [60/100] Step [50/250] Loss_G: 1.3462 Loss_DX: 0.1783 Loss_DY: 0.1388
# [CycleGAN] Epoch [60/100] Step [100/250] Loss_G: 1.2520 Loss_DX: 0.2325 Loss_DY: 0.2380
# [CycleGAN] Epoch [60/100] Step [150/250] Loss_G: 1.3627 Loss_DX: 0.1460 Loss_DY: 0.1044
# [CycleGAN] Epoch [60/100] Step [200/250] Loss_G: 1.3237 Loss_DX: 0.2255 Loss_DY: 0.2084
# [CycleGAN] Epoch [61/100] Step [0/250] Loss_G: 1.2316 Loss_DX: 0.2316 Loss_DY: 0.1392
# [CycleGAN] Epoch [61/100] Step [50/250] Loss_G: 1.5387 Loss_DX: 0.1235 Loss_DY: 0.1484
# [CycleGAN] Epoch [61/100] Step [100/250] Loss_G: 1.3089 Loss_DX: 0.1553 Loss_DY: 0.3112
# [CycleGAN] Epoch [61/100] Step [150/250] Loss_G: 1.5761 Loss_DX: 0.1352 Loss_DY: 0.1433
# [CycleGAN] Epoch [61/100] Step [200/250] Loss_G: 1.5670 Loss_DX: 0.3332 Loss_DY: 0.1536
# [CycleGAN] Epoch [62/100] Step [0/250] Loss_G: 1.4314 Loss_DX: 0.1403 Loss_DY: 0.1547
# [CycleGAN] Epoch [67/100] Step [0/250] Loss_G: 1.1504 Loss_DX: 0.0820 Loss_DY: 0.2025
# [CycleGAN] Epoch [67/100] Step [50/250] Loss_G: 1.1337 Loss_DX: 0.1265 Loss_DY: 0.2006
# [CycleGAN] Epoch [67/100] Step [100/250] Loss_G: 0.8854 Loss_DX: 0.1625 Loss_DY: 0.2186
# [CycleGAN] Epoch [67/100] Step [150/250] Loss_G: 1.1579 Loss_DX: 0.1489 Loss_DY: 0.2648
# [CycleGAN] Epoch [67/100] Step [200/250] Loss_G: 0.9183 Loss_DX: 0.2202 Loss_DY: 0.2518
# [CycleGAN] Epoch [68/100] Step [0/250] Loss_G: 0.9994 Loss_DX: 0.1685 Loss_DY: 0.2578
# [CycleGAN] Epoch [68/100] Step [50/250] Loss_G: 0.9638 Loss_DX: 0.2627 Loss_DY: 0.2496
# [CycleGAN] Epoch [68/100] Step [100/250] Loss_G: 0.8507 Loss_DX: 0.2099 Loss_DY: 0.2217
# [CycleGAN] Epoch [68/100] Step [150/250] Loss_G: 0.8558 Loss_DX: 0.2046 Loss_DY: 0.2506
# [CycleGAN] Epoch [68/100] Step [200/250] Loss_G: 0.8760 Loss_DX: 0.0986 Loss_DY: 0.2358
# [CycleGAN] Epoch [69/100] Step [0/250] Loss_G: 0.9803 Loss_DX: 0.2136 Loss_DY: 0.2570
# [CycleGAN] Epoch [69/100] Step [50/250] Loss_G: 1.6296 Loss_DX: 0.2656 Loss_DY: 0.2344
# [CycleGAN] Epoch [69/100] Step [100/250] Loss_G: 0.7934 Loss_DX: 0.1803 Loss_DY: 0.2491
# [CycleGAN] Epoch [69/100] Step [150/250] Loss_G: 0.9072 Loss_DX: 0.2139 Loss_DY: 0.2795
# [CycleGAN] Epoch [69/100] Step [200/250] Loss_G: 1.0908 Loss_DX: 0.1663 Loss_DY: 0.2849
# [CycleGAN] Epoch [70/100] Step [0/250] Loss_G: 1.2441 Loss_DX: 0.1179 Loss_DY: 0.2396
# [CycleGAN] Epoch [70/100] Step [50/250] Loss_G: 0.8205 Loss_DX: 0.2026 Loss_DY: 0.2512
# [CycleGAN] Epoch [70/100] Step [100/250] Loss_G: 1.0307 Loss_DX: 0.1004 Loss_DY: 0.2426
# [CycleGAN] Epoch [70/100] Step [150/250] Loss_G: 1.0779 Loss_DX: 0.1443 Loss_DY: 0.2389
# [CycleGAN] Epoch [70/100] Step [200/250] Loss_G: 1.2919 Loss_DX: 0.2313 Loss_DY: 0.2674
# [CycleGAN] Epoch [71/100] Step [0/250] Loss_G: 1.0210 Loss_DX: 0.1291 Loss_DY: 0.2566
# [CycleGAN] Epoch [71/100] Step [50/250] Loss_G: 0.9822 Loss_DX: 0.1351 Loss_DY: 0.2503
# [CycleGAN] Epoch [71/100] Step [100/250] Loss_G: 1.1868 Loss_DX: 0.1349 Loss_DY: 0.2572
# [CycleGAN] Epoch [71/100] Step [150/250] Loss_G: 1.1343 Loss_DX: 0.2073 Loss_DY: 0.2418
# [CycleGAN] Epoch [71/100] Step [200/250] Loss_G: 0.9194 Loss_DX: 0.2482 Loss_DY: 0.2330
# [CycleGAN] Epoch [72/100] Step [0/250] Loss_G: 0.9471 Loss_DX: 0.2178 Loss_DY: 0.2868
# [CycleGAN] Epoch [72/100] Step [50/250] Loss_G: 0.7931 Loss_DX: 0.2462 Loss_DY: 0.2149
# [CycleGAN] Epoch [72/100] Step [100/250] Loss_G: 1.1271 Loss_DX: 0.2432 Loss_DY: 0.2544
# [CycleGAN] Epoch [72/100] Step [150/250] Loss_G: 1.2085 Loss_DX: 0.1451 Loss_DY: 0.2236
# [CycleGAN] Epoch [72/100] Step [200/250] Loss_G: 0.9743 Loss_DX: 0.0942 Loss_DY: 0.2434
# [CycleGAN] Epoch [73/100] Step [0/250] Loss_G: 1.0759 Loss_DX: 0.1268 Loss_DY: 0.2703
# [CycleGAN] Epoch [73/100] Step [50/250] Loss_G: 0.7945 Loss_DX: 0.1247 Loss_DY: 0.2673
# [CycleGAN] Epoch [73/100] Step [100/250] Loss_G: 1.3478 Loss_DX: 0.1597 Loss_DY: 0.2278
# [CycleGAN] Epoch [73/100] Step [150/250] Loss_G: 1.2759 Loss_DX: 0.1970 Loss_DY: 0.2421
# [CycleGAN] Epoch [73/100] Step [200/250] Loss_G: 1.2465 Loss_DX: 0.2042 Loss_DY: 0.2628
# [CycleGAN] Epoch [74/100] Step [0/250] Loss_G: 1.2217 Loss_DX: 0.1417 Loss_DY: 0.2863
# [CycleGAN] Epoch [74/100] Step [50/250] Loss_G: 1.2164 Loss_DX: 0.2744 Loss_DY: 0.2719
# [CycleGAN] Epoch [74/100] Step [100/250] Loss_G: 0.9992 Loss_DX: 0.0794 Loss_DY: 0.3109
# [CycleGAN] Epoch [74/100] Step [150/250] Loss_G: 1.1334 Loss_DX: 0.0796 Loss_DY: 0.2034
# [CycleGAN] Epoch [74/100] Step [200/250] Loss_G: 1.1505 Loss_DX: 0.0752 Loss_DY: 0.2330
# [CycleGAN] Epoch [75/100] Step [0/250] Loss_G: 1.0474 Loss_DX: 0.0499 Loss_DY: 0.2463
# [CycleGAN] Epoch [75/100] Step [50/250] Loss_G: 1.0180 Loss_DX: 0.2239 Loss_DY: 0.2583
# [CycleGAN] Epoch [75/100] Step [100/250] Loss_G: 1.1420 Loss_DX: 0.1811 Loss_DY: 0.1908
# [CycleGAN] Epoch [75/100] Step [150/250] Loss_G: 0.9355 Loss_DX: 0.1681 Loss_DY: 0.2564
# [CycleGAN] Epoch [75/100] Step [200/250] Loss_G: 1.2345 Loss_DX: 0.2163 Loss_DY: 0.2212
# [CycleGAN] Epoch [76/100] Step [0/250] Loss_G: 1.0694 Loss_DX: 0.1168 Loss_DY: 0.2557
# [CycleGAN] Epoch [76/100] Step [50/250] Loss_G: 1.0846 Loss_DX: 0.1183 Loss_DY: 0.2368
# [CycleGAN] Epoch [76/100] Step [100/250] Loss_G: 0.9067 Loss_DX: 0.2203 Loss_DY: 0.2509
# [CycleGAN] Epoch [76/100] Step [150/250] Loss_G: 1.2237 Loss_DX: 0.2109 Loss_DY: 0.2278
# [CycleGAN] Epoch [76/100] Step [200/250] Loss_G: 0.9514 Loss_DX: 0.1897 Loss_DY: 0.2318
# [CycleGAN] Epoch [77/100] Step [0/250] Loss_G: 1.0665 Loss_DX: 0.1934 Loss_DY: 0.2351
# [CycleGAN] Epoch [77/100] Step [50/250] Loss_G: 1.1087 Loss_DX: 0.1359 Loss_DY: 0.2154
# [CycleGAN] Epoch [77/100] Step [100/250] Loss_G: 0.9750 Loss_DX: 0.1772 Loss_DY: 0.2580
# [CycleGAN] Epoch [77/100] Step [150/250] Loss_G: 1.2098 Loss_DX: 0.1327 Loss_DY: 0.2220
# [CycleGAN] Epoch [77/100] Step [200/250] Loss_G: 1.2184 Loss_DX: 0.1447 Loss_DY: 0.2117
# [CycleGAN] Epoch [78/100] Step [0/250] Loss_G: 1.3995 Loss_DX: 0.1844 Loss_DY: 0.2108
# [CycleGAN] Epoch [78/100] Step [50/250] Loss_G: 1.1105 Loss_DX: 0.1551 Loss_DY: 0.2169
# [CycleGAN] Epoch [78/100] Step [100/250] Loss_G: 1.3698 Loss_DX: 0.1345 Loss_DY: 0.2066
# [CycleGAN] Epoch [78/100] Step [150/250] Loss_G: 1.1842 Loss_DX: 0.1426 Loss_DY: 0.1778
# [CycleGAN] Epoch [78/100] Step [200/250] Loss_G: 1.2686 Loss_DX: 0.0948 Loss_DY: 0.1970
# [CycleGAN] Epoch [79/100] Step [0/250] Loss_G: 1.5684 Loss_DX: 0.1299 Loss_DY: 0.1562
# [CycleGAN] Epoch [79/100] Step [50/250] Loss_G: 1.1861 Loss_DX: 0.1090 Loss_DY: 0.1688
# [CycleGAN] Epoch [79/100] Step [100/250] Loss_G: 1.5482 Loss_DX: 0.0748 Loss_DY: 0.1391
# [CycleGAN] Epoch [79/100] Step [150/250] Loss_G: 1.1841 Loss_DX: 0.1274 Loss_DY: 0.2075
# [CycleGAN] Epoch [79/100] Step [200/250] Loss_G: 1.2995 Loss_DX: 0.1142 Loss_DY: 0.2493
# [CycleGAN] Epoch [80/100] Step [0/250] Loss_G: 1.4922 Loss_DX: 0.1572 Loss_DY: 0.1634
# [CycleGAN] Epoch [80/100] Step [50/250] Loss_G: 1.4068 Loss_DX: 0.2403 Loss_DY: 0.1623
# [CycleGAN] Epoch [80/100] Step [100/250] Loss_G: 1.0455 Loss_DX: 0.2908 Loss_DY: 0.1457
# [CycleGAN] Epoch [80/100] Step [150/250] Loss_G: 1.3924 Loss_DX: 0.1391 Loss_DY: 0.2261
# [CycleGAN] Epoch [80/100] Step [200/250] Loss_G: 1.3357 Loss_DX: 0.0716 Loss_DY: 0.1132
# [CycleGAN] Epoch [81/100] Step [0/250] Loss_G: 1.5451 Loss_DX: 0.1105 Loss_DY: 0.1473
# [CycleGAN] Epoch [81/100] Step [50/250] Loss_G: 1.4122 Loss_DX: 0.1510 Loss_DY: 0.1895
# [CycleGAN] Epoch [81/100] Step [100/250] Loss_G: 1.0694 Loss_DX: 0.1895 Loss_DY: 0.2254
# [CycleGAN] Epoch [81/100] Step [150/250] Loss_G: 1.4229 Loss_DX: 0.1681 Loss_DY: 0.1131
# [CycleGAN] Epoch [81/100] Step [200/250] Loss_G: 1.7180 Loss_DX: 0.0864 Loss_DY: 0.1036
# [CycleGAN] Epoch [82/100] Step [0/250] Loss_G: 0.9631 Loss_DX: 0.2011 Loss_DY: 0.1739
# [CycleGAN] Epoch [82/100] Step [50/250] Loss_G: 1.3518 Loss_DX: 0.1818 Loss_DY: 0.1996
# [CycleGAN] Epoch [82/100] Step [100/250] Loss_G: 1.6457 Loss_DX: 0.2007 Loss_DY: 0.1772
# [CycleGAN] Epoch [82/100] Step [150/250] Loss_G: 1.5316 Loss_DX: 0.2287 Loss_DY: 0.1641
# [CycleGAN] Epoch [82/100] Step [200/250] Loss_G: 1.4888 Loss_DX: 0.1894 Loss_DY: 0.1528
# [CycleGAN] Epoch [83/100] Step [0/250] Loss_G: 0.9970 Loss_DX: 0.1740 Loss_DY: 0.1667
# [CycleGAN] Epoch [83/100] Step [50/250] Loss_G: 1.2873 Loss_DX: 0.1794 Loss_DY: 0.1741
# [CycleGAN] Epoch [83/100] Step [100/250] Loss_G: 0.9416 Loss_DX: 0.2341 Loss_DY: 0.1902
# [CycleGAN] Epoch [83/100] Step [150/250] Loss_G: 1.1636 Loss_DX: 0.1856 Loss_DY: 0.1702
# [CycleGAN] Epoch [83/100] Step [200/250] Loss_G: 1.3386 Loss_DX: 0.1840 Loss_DY: 0.1705
# [CycleGAN] Epoch [84/100] Step [0/250] Loss_G: 1.1831 Loss_DX: 0.1640 Loss_DY: 0.2076
# [CycleGAN] Epoch [84/100] Step [50/250] Loss_G: 0.8500 Loss_DX: 0.1842 Loss_DY: 0.2652
# [CycleGAN] Epoch [84/100] Step [100/250] Loss_G: 1.1853 Loss_DX: 0.1867 Loss_DY: 0.1481
# [CycleGAN] Epoch [84/100] Step [150/250] Loss_G: 1.8317 Loss_DX: 0.1153 Loss_DY: 0.1046
# [CycleGAN] Epoch [84/100] Step [200/250] Loss_G: 1.4031 Loss_DX: 0.2197 Loss_DY: 0.1196
# [CycleGAN] Epoch [85/100] Step [0/250] Loss_G: 0.9405 Loss_DX: 0.1435 Loss_DY: 0.2211
# [CycleGAN] Epoch [85/100] Step [50/250] Loss_G: 1.2460 Loss_DX: 0.1977 Loss_DY: 0.1251
# [CycleGAN] Epoch [85/100] Step [100/250] Loss_G: 1.4887 Loss_DX: 0.1191 Loss_DY: 0.1714
# [CycleGAN] Epoch [85/100] Step [150/250] Loss_G: 1.3366 Loss_DX: 0.1188 Loss_DY: 0.2110
# [CycleGAN] Epoch [85/100] Step [200/250] Loss_G: 1.4233 Loss_DX: 0.2945 Loss_DY: 0.2772
# [CycleGAN] Epoch [86/100] Step [0/250] Loss_G: 1.2073 Loss_DX: 0.1543 Loss_DY: 0.1443
# [CycleGAN] Epoch [86/100] Step [50/250] Loss_G: 1.3610 Loss_DX: 0.1688 Loss_DY: 0.1585
# [CycleGAN] Epoch [86/100] Step [100/250] Loss_G: 1.3153 Loss_DX: 0.1377 Loss_DY: 0.1227
# [CycleGAN] Epoch [86/100] Step [150/250] Loss_G: 1.0606 Loss_DX: 0.2545 Loss_DY: 0.1521
# [CycleGAN] Epoch [86/100] Step [200/250] Loss_G: 1.3377 Loss_DX: 0.1594 Loss_DY: 0.1301
# [CycleGAN] Epoch [87/100] Step [0/250] Loss_G: 1.2405 Loss_DX: 0.1949 Loss_DY: 0.1483
# [CycleGAN] Epoch [87/100] Step [50/250] Loss_G: 1.4009 Loss_DX: 0.1622 Loss_DY: 0.1528
# [CycleGAN] Epoch [87/100] Step [100/250] Loss_G: 1.3176 Loss_DX: 0.2006 Loss_DY: 0.2528
# [CycleGAN] Epoch [87/100] Step [150/250] Loss_G: 1.0853 Loss_DX: 0.2297 Loss_DY: 0.2889
# [CycleGAN] Epoch [87/100] Step [200/250] Loss_G: 1.1863 Loss_DX: 0.1248 Loss_DY: 0.2408
# [CycleGAN] Epoch [88/100] Step [0/250] Loss_G: 1.0906 Loss_DX: 0.3078 Loss_DY: 0.2211
# [CycleGAN] Epoch [88/100] Step [50/250] Loss_G: 0.9772 Loss_DX: 0.1185 Loss_DY: 0.1957
# [CycleGAN] Epoch [88/100] Step [100/250] Loss_G: 1.4941 Loss_DX: 0.1098 Loss_DY: 0.1580
# [CycleGAN] Epoch [88/100] Step [150/250] Loss_G: 1.2803 Loss_DX: 0.1793 Loss_DY: 0.1560
# [CycleGAN] Epoch [88/100] Step [200/250] Loss_G: 1.0940 Loss_DX: 0.2932 Loss_DY: 0.1769
# [CycleGAN] Epoch [89/100] Step [0/250] Loss_G: 1.3664 Loss_DX: 0.1955 Loss_DY: 0.2205
# [CycleGAN] Epoch [89/100] Step [50/250] Loss_G: 1.3862 Loss_DX: 0.1636 Loss_DY: 0.1328
# [CycleGAN] Epoch [89/100] Step [100/250] Loss_G: 1.4401 Loss_DX: 0.1220 Loss_DY: 0.1935
# [CycleGAN] Epoch [89/100] Step [150/250] Loss_G: 1.0838 Loss_DX: 0.1854 Loss_DY: 0.1591
# [CycleGAN] Epoch [89/100] Step [200/250] Loss_G: 1.4507 Loss_DX: 0.1685 Loss_DY: 0.1820
# [CycleGAN] Epoch [90/100] Step [0/250] Loss_G: 1.2618 Loss_DX: 0.1717 Loss_DY: 0.1575
# [CycleGAN] Epoch [90/100] Step [50/250] Loss_G: 1.1594 Loss_DX: 0.1490 Loss_DY: 0.1323
# [CycleGAN] Epoch [90/100] Step [100/250] Loss_G: 1.2245 Loss_DX: 0.1913 Loss_DY: 0.1252
# [CycleGAN] Epoch [90/100] Step [150/250] Loss_G: 1.2154 Loss_DX: 0.2019 Loss_DY: 0.1495
# [CycleGAN] Epoch [90/100] Step [200/250] Loss_G: 1.4221 Loss_DX: 0.0735 Loss_DY: 0.1949
# [CycleGAN] Epoch [91/100] Step [0/250] Loss_G: 1.1095 Loss_DX: 0.1499 Loss_DY: 0.1157
# [CycleGAN] Epoch [91/100] Step [50/250] Loss_G: 1.2645 Loss_DX: 0.1986 Loss_DY: 0.1476
# [CycleGAN] Epoch [91/100] Step [100/250] Loss_G: 1.5236 Loss_DX: 0.1339 Loss_DY: 0.1466
# [CycleGAN] Epoch [91/100] Step [150/250] Loss_G: 1.4828 Loss_DX: 0.2437 Loss_DY: 0.1329
# [CycleGAN] Epoch [91/100] Step [200/250] Loss_G: 1.1837 Loss_DX: 0.1678 Loss_DY: 0.1343
# [CycleGAN] Epoch [92/100] Step [0/250] Loss_G: 1.1546 Loss_DX: 0.2079 Loss_DY: 0.1784
# [CycleGAN] Epoch [92/100] Step [50/250] Loss_G: 0.9924 Loss_DX: 0.1687 Loss_DY: 0.1746
# [CycleGAN] Epoch [92/100] Step [100/250] Loss_G: 1.2500 Loss_DX: 0.1303 Loss_DY: 0.1615
# [CycleGAN] Epoch [92/100] Step [150/250] Loss_G: 1.2887 Loss_DX: 0.1731 Loss_DY: 0.0981
# [CycleGAN] Epoch [92/100] Step [200/250] Loss_G: 1.3619 Loss_DX: 0.1550 Loss_DY: 0.1852
# [CycleGAN] Epoch [93/100] Step [0/250] Loss_G: 1.5980 Loss_DX: 0.1378 Loss_DY: 0.1080
# [CycleGAN] Epoch [93/100] Step [50/250] Loss_G: 1.2287 Loss_DX: 0.1715 Loss_DY: 0.2275
# [CycleGAN] Epoch [93/100] Step [100/250] Loss_G: 1.2082 Loss_DX: 0.1398 Loss_DY: 0.2066
# [CycleGAN] Epoch [93/100] Step [150/250] Loss_G: 1.2497 Loss_DX: 0.0961 Loss_DY: 0.1452
# [CycleGAN] Epoch [93/100] Step [200/250] Loss_G: 1.1370 Loss_DX: 0.1296 Loss_DY: 0.1268
# [CycleGAN] Epoch [94/100] Step [0/250] Loss_G: 1.1903 Loss_DX: 0.1980 Loss_DY: 0.1029
# [CycleGAN] Epoch [94/100] Step [50/250] Loss_G: 1.2286 Loss_DX: 0.1139 Loss_DY: 0.1504
# [CycleGAN] Epoch [94/100] Step [100/250] Loss_G: 1.6235 Loss_DX: 0.1452 Loss_DY: 0.1552
# [CycleGAN] Epoch [94/100] Step [150/250] Loss_G: 1.3476 Loss_DX: 0.2211 Loss_DY: 0.2054
# [CycleGAN] Epoch [94/100] Step [200/250] Loss_G: 1.2354 Loss_DX: 0.1351 Loss_DY: 0.1105
# [CycleGAN] Epoch [95/100] Step [0/250] Loss_G: 1.1176 Loss_DX: 0.1701 Loss_DY: 0.2030
# [CycleGAN] Epoch [95/100] Step [50/250] Loss_G: 1.3430 Loss_DX: 0.1526 Loss_DY: 0.1104
# [CycleGAN] Epoch [95/100] Step [100/250] Loss_G: 1.3443 Loss_DX: 0.1939 Loss_DY: 0.1885
# [CycleGAN] Epoch [95/100] Step [150/250] Loss_G: 1.6078 Loss_DX: 0.1882 Loss_DY: 0.1792
# [CycleGAN] Epoch [95/100] Step [200/250] Loss_G: 1.1054 Loss_DX: 0.1524 Loss_DY: 0.1089
# [CycleGAN] Epoch [96/100] Step [0/250] Loss_G: 1.2698 Loss_DX: 0.1077 Loss_DY: 0.0990
# [CycleGAN] Epoch [96/100] Step [50/250] Loss_G: 1.3026 Loss_DX: 0.1028 Loss_DY: 0.1237
# [CycleGAN] Epoch [96/100] Step [100/250] Loss_G: 1.3884 Loss_DX: 0.1324 Loss_DY: 0.1262
# [CycleGAN] Epoch [96/100] Step [150/250] Loss_G: 1.5679 Loss_DX: 0.2104 Loss_DY: 0.0960
# [CycleGAN] Epoch [96/100] Step [200/250] Loss_G: 1.1951 Loss_DX: 0.1110 Loss_DY: 0.1055
# [CycleGAN] Epoch [97/100] Step [0/250] Loss_G: 1.3319 Loss_DX: 0.1183 Loss_DY: 0.2027
# [CycleGAN] Epoch [97/100] Step [50/250] Loss_G: 1.4475 Loss_DX: 0.1978 Loss_DY: 0.1961
# [CycleGAN] Epoch [97/100] Step [100/250] Loss_G: 1.0575 Loss_DX: 0.1945 Loss_DY: 0.1539
# [CycleGAN] Epoch [97/100] Step [150/250] Loss_G: 1.2269 Loss_DX: 0.1424 Loss_DY: 0.1738
# [CycleGAN] Epoch [97/100] Step [200/250] Loss_G: 1.1939 Loss_DX: 0.1592 Loss_DY: 0.1367
# [CycleGAN] Epoch [98/100] Step [0/250] Loss_G: 0.9144 Loss_DX: 0.2158 Loss_DY: 0.1403
# [CycleGAN] Epoch [98/100] Step [50/250] Loss_G: 1.4042 Loss_DX: 0.1620 Loss_DY: 0.1861
# [CycleGAN] Epoch [98/100] Step [100/250] Loss_G: 1.3716 Loss_DX: 0.1127 Loss_DY: 0.1041
# [CycleGAN] Epoch [98/100] Step [150/250] Loss_G: 1.6202 Loss_DX: 0.2245 Loss_DY: 0.1735
# [CycleGAN] Epoch [98/100] Step [200/250] Loss_G: 1.2222 Loss_DX: 0.0819 Loss_DY: 0.1400
# [CycleGAN] Epoch [99/100] Step [0/250] Loss_G: 1.5621 Loss_DX: 0.1521 Loss_DY: 0.1843
# [CycleGAN] Epoch [99/100] Step [50/250] Loss_G: 1.3458 Loss_DX: 0.1114 Loss_DY: 0.1221
# [CycleGAN] Epoch [99/100] Step [100/250] Loss_G: 1.5893 Loss_DX: 0.1803 Loss_DY: 0.2171
# [CycleGAN] Epoch [99/100] Step [150/250] Loss_G: 1.4214 Loss_DX: 0.1790 Loss_DY: 0.0977
# [CycleGAN] Epoch [99/100] Step [200/250] Loss_G: 1.6571 Loss_DX: 0.1982 Loss_DY: 0.1885
# [CycleGAN] Epoch [100/100] Step [0/250] Loss_G: 1.4800 Loss_DX: 0.1794 Loss_DY: 0.1396
# [CycleGAN] Epoch [100/100] Step [50/250] Loss_G: 1.1544 Loss_DX: 0.1915 Loss_DY: 0.1420
# [CycleGAN] Epoch [100/100] Step [100/250] Loss_G: 1.3068 Loss_DX: 0.2029 Loss_DY: 0.1480
# [CycleGAN] Epoch [100/100] Step [150/250] Loss_G: 1.0296 Loss_DX: 0.1936 Loss_DY: 0.1760
# [CycleGAN] Epoch [100/100] Step [200/250] Loss_G: 1.5872 Loss_DX: 0.1437 Loss_DY: 0.1530
# Huấn luyện CycleGAN xong, ảnh kết quả trong: /kaggle/working/outputs_cyclegan_toy
